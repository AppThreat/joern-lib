# %% [markdown]
# # connman
#
# A vulnerability in connman was used to hack a [Tesla Model X](https://youtu.be/krSj81thN0w?t=2183). The vulnerability was found using fuzzing by a team of security researchers. The goal of this exercise is to find the particular vulnerability statically.
#
# We begin by setting up the basics for joern.

# %%
import asyncio

from joern_lib import client, workspace
from joern_lib.detectors import common as cpg, c
from joern_lib.utils import print_table

joern_host = "http://joern:9000"
cpggen_host = "http://cpggen:7072"
joern_username = "admin"
joern_password  = "admin"

# %% [markdown]
# ## Clone the vulnerable repo
#
# We clone the vulnerable [repo](https://github.com/helium/connman) using GitPython and importing to joern using import_code api.

# %%
import git
import os

if not os.path.exists("/tmp/connman"):
    try:
        git.Repo.clone_from("https://github.com/helium/connman", "/tmp/connman", branch="master", depth=1)
    except Exception as e:
        print(e)
else:
    print("/tmp/connman already exists")
# Out:
# /tmp/connman already exists

# %%
async def create_workspace():
    connection = await client.get(joern_host, cpggen_host, joern_username, joern_password)
    res = await workspace.import_code(connection, "/tmp/connman", "connman");
    print (res)
asyncio.run(create_workspace())
# Out:
# ╭─────────── CPGQL Query ────────────╮
# │ os.exists(os.Path("/tmp/connman")) │
# ╰────────────────────────────────────╯
# ╭───────────── CPGQL Query ─────────────╮
# │ importCode("/tmp/connman", "connman") │
# ╰───────────────────────────────────────╯
# ╭─ CPGQL Query ─╮
# │ save          │
# ╰───────────────╯
# True

# %% [markdown]
# ## Detect dangerous string copy functions used
#
# Avoid `strcpy` or `strncpy` function. `strcpy` does not check buffer lengths. A possible mitigation could be `strncpy` which could prevent buffer overflows but does not null-terminate strings leading to memory corruption (Out-of-bounds write). A secure alternative (on BSD) is `strlcpy`.

# %%
async def dangerous_string_fn():
    connection = await client.get(joern_host, cpggen_host, joern_username, joern_password)
    res = await c.get_strcpy(connection)
    print_table (res, title="Dangerous string functions usage")
asyncio.run(dangerous_string_fn())
# Out:
# ╭────────────────────────── CPGQL Query ──────────────────────────╮
# │ cpg.method("(?i)(strcpy|strncpy)").callIn.location.toJsonPretty │
# ╰─────────────────────────────────────────────────────────────────╯
#                                                                           Dangerous string functions usage
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ packageName ┃ symbol           ┃ filename         ┃ className       ┃ methodFullName   ┃ lineNumber ┃ classShortName ┃ methodShortName ┃ node             ┃ _label   ┃ nodeLabel ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━┩
# │ <global>    │ strncpy(pathname │ src/timezone.c   │ src/timezone.c: │ find_origin      │        163 │ <global>       │ find_origin     │ {                │ LOCATION │ CALL      │
# │             │ , basepath,      │                  │ <global>        │                  │            │                │                 │   "name": "strnc │          │           │
# │             │ sizeof(pathname) │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │ - 1)             │                  │                 │                  │            │                │                 │   "code": "strnc │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 1,    │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 10808    │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strncpy(pathname │ src/timezone.c   │ src/timezone.c: │ find_origin      │        209 │ <global>       │ find_origin     │ {                │ LOCATION │ CALL      │
# │             │ , d->d_name,     │                  │ <global>        │                  │            │                │                 │   "name": "strnc │          │           │
# │             │ sizeof(pathname) │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │ )                │                  │                 │                  │            │                │                 │   "code": "strnc │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 1,    │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 10960    │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strncpy(dns_name │ gdhcp/client.c   │ gdhcp/client.c: │ get_domains      │       2123 │ <global>       │ get_domains     │ {                │ LOCATION │ CALL      │
# │             │ , (char          │                  │ <global>        │                  │            │                │                 │   "name": "strnc │          │           │
# │             │ *)&value,        │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │ NS_MAXDNAME)     │                  │                 │                  │            │                │                 │   "code": "strnc │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 1,    │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 86622    │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strncpy(ifr.ifr_ │ tools/tap-test.c │ tools/tap-test. │ inet_ifup        │         51 │ <global>       │ inet_ifup       │ {                │ LOCATION │ CALL      │
# │             │ name, ifname,    │                  │ c:<global>      │                  │            │                │                 │   "name": "strnc │          │           │
# │             │ sizeof(ifr.ifr_n │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │ ame) - 1)        │                  │                 │                  │            │                │                 │   "code": "strnc │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 7,    │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 120003   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strncpy(ifr.ifr_ │ tools/tap-test.c │ tools/tap-test. │ create_tap       │         91 │ <global>       │ create_tap      │ {                │ LOCATION │ CALL      │
# │             │ name, ifname,    │                  │ c:<global>      │                  │            │                │                 │   "name": "strnc │          │           │
# │             │ sizeof(ifr.ifr_n │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │ ame) - 1)        │                  │                 │                  │            │                │                 │   "code": "strnc │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 8,    │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 120105   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strncpy(wrq.ifr_ │ src/rtnl.c       │ src/rtnl.c:<glo │ wext_interface   │        107 │ <global>       │ wext_interface  │ {                │ LOCATION │ CALL      │
# │             │ name, ifname,    │                  │ bal>            │                  │            │                │                 │   "name": "strnc │          │           │
# │             │ sizeof(wrq.ifr_n │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │ ame) - 1)        │                  │                 │                  │            │                │                 │   "code": "strnc │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 7,    │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 127414   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strncpy(vifr.dev │ plugins/ethernet │ plugins/etherne │ get_vlan_vid     │         76 │ <global>       │ get_vlan_vid    │ {                │ LOCATION │ CALL      │
# │             │ ice1, ifname,    │ .c               │ t.c:<global>    │                  │            │                │                 │   "name": "strnc │          │           │
# │             │ sizeof(vifr.devi │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │ ce1))            │                  │                 │                  │            │                │                 │   "code": "strnc │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 8,    │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 188559   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strncpy(ifr.ifr_ │ plugins/ethernet │ plugins/etherne │ get_dsa_port     │        102 │ <global>       │ get_dsa_port    │ {                │ LOCATION │ CALL      │
# │             │ name, ifname,    │ .c               │ t.c:<global>    │                  │            │                │                 │   "name": "strnc │          │           │
# │             │ sizeof(ifr.ifr_n │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │ ame))            │                  │                 │                  │            │                │                 │   "code": "strnc │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 11,   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 188629   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strncpy(vifr.dev │ plugins/ethernet │ plugins/etherne │ get_dsa_port     │        106 │ <global>       │ get_dsa_port    │ {                │ LOCATION │ CALL      │
# │             │ ice1, ifname,    │ .c               │ t.c:<global>    │                  │            │                │                 │   "name": "strnc │          │           │
# │             │ sizeof(vifr.devi │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │ ce1))            │                  │                 │                  │            │                │                 │   "code": "strnc │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 13,   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 188643   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strncpy(ifr.ifr_ │ plugins/ethernet │ plugins/etherne │ get_dsa_port     │        109 │ <global>       │ get_dsa_port    │ {                │ LOCATION │ CALL      │
# │             │ name,            │ .c               │ t.c:<global>    │                  │            │                │                 │   "name": "strnc │          │           │
# │             │ vifr.u.device2,  │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │ sizeof(ifr.ifr_n │                  │                 │                  │            │                │                 │   "code": "strnc │          │           │
# │             │ ame))            │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 1,    │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 188661   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strncpy(p.name,  │ src/6to4.c       │ src/6to4.c:<glo │ tunnel_create    │         80 │ <global>       │ tunnel_create   │ {                │ LOCATION │ CALL      │
# │             │ "tun6to4",       │                  │ bal>            │                  │            │                │                 │   "name": "strnc │          │           │
# │             │ sizeof(p.name) - │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │ 1)               │                  │                 │                  │            │                │                 │   "code": "strnc │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 13,   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 191297   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strncpy(ifr.ifr_ │ src/6to4.c       │ src/6to4.c:<glo │ tunnel_create    │         82 │ <global>       │ tunnel_create   │ {                │ LOCATION │ CALL      │
# │             │ name, "sit0",    │                  │ bal>            │                  │            │                │                 │   "name": "strnc │          │           │
# │             │ sizeof(ifr.ifr_n │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │ ame) - 1)        │                  │                 │                  │            │                │                 │   "code": "strnc │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 14,   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 191308   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strncpy(p.name,  │ src/6to4.c       │ src/6to4.c:<glo │ tunnel_destroy   │        114 │ <global>       │ tunnel_destroy  │ {                │ LOCATION │ CALL      │
# │             │ "tun6to4",       │                  │ bal>            │                  │            │                │                 │   "name": "strnc │          │           │
# │             │ sizeof(p.name) - │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │ 1)               │                  │                 │                  │            │                │                 │   "code": "strnc │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 12,   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 191419   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strncpy(ifr.ifr_ │ src/6to4.c       │ src/6to4.c:<glo │ tunnel_destroy   │        116 │ <global>       │ tunnel_destroy  │ {                │ LOCATION │ CALL      │
# │             │ name, "tun6to4", │                  │ bal>            │                  │            │                │                 │   "name": "strnc │          │           │
# │             │ sizeof(ifr.ifr_n │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │ ame) - 1)        │                  │                 │                  │            │                │                 │   "code": "strnc │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 13,   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 191430   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strncpy(question │ src/dnsproxy.c   │ src/dnsproxy.c: │ parse_response   │       1006 │ <global>       │ parse_response  │ {                │ LOCATION │ CALL      │
# │             │ , (char *) ptr,  │                  │ <global>        │                  │            │                │                 │   "name": "strnc │          │           │
# │             │ qlen)            │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "code": "strnc │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 25,   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 203999   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strncpy(dns_name │ src/dnsproxy.c   │ src/dnsproxy.c: │ cache_refresh_en │       1332 │ <global>       │ cache_refresh_e │ {                │ LOCATION │ CALL      │
# │             │ , entry->key,    │                  │ <global>        │ try              │            │                │ ntry            │   "name": "strnc │          │           │
# │             │ NS_MAXDNAME)     │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "code": "strnc │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 4,    │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 204662   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strncpy(uptr,    │ src/dnsproxy.c   │ src/dnsproxy.c: │ uncompress       │       1791 │ <global>       │ uncompress      │ {                │ LOCATION │ CALL      │
# │             │ name, uncomp_len │                  │ <global>        │                  │            │                │                 │   "name": "strnc │          │           │
# │             │ - (uptr -        │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │ uncompressed))   │                  │                 │                  │            │                │                 │   "code": "strnc │          │           │
# ...
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 65960    │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strcpy(username, │ scripts/libppp-p │ scripts/libppp- │ ppp_get_secret   │        132 │ <global>       │ ppp_get_secret  │ {                │ LOCATION │ CALL      │
# │             │ user)            │ lugin.c          │ plugin.c:<globa │                  │            │                │                 │   "name": "strcp │          │           │
# │             │                  │                  │ l>              │                  │            │                │                 │   "signature": " │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "code": "strcp │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 1,    │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 216850   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strcpy(password, │ scripts/libppp-p │ scripts/libppp- │ ppp_get_secret   │        134 │ <global>       │ ppp_get_secret  │ {                │ LOCATION │ CALL      │
# │             │ pass)            │ lugin.c          │ plugin.c:<globa │                  │            │                │                 │   "name": "strcp │          │           │
# │             │                  │                  │ l>              │                  │            │                │                 │   "signature": " │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "code": "strcp │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 19,   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 216853   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strcpy(buf,      │ scripts/libppp-p │ scripts/libppp- │ ppp_up           │        178 │ <global>       │ ppp_up          │ {                │ LOCATION │ CALL      │
# │             │ "255.255.255.255 │ lugin.c          │ plugin.c:<globa │                  │            │                │                 │   "name": "strcp │          │           │
# │             │ ")               │                  │ l>              │                  │            │                │                 │   "signature": " │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "code": "strcp │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 21,   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 216940   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strcpy(ifr.ifr_n │ plugins/loopback │ plugins/loopbac │ setup_loopback   │        142 │ <global>       │ setup_loopback  │ {                │ LOCATION │ CALL      │
# │             │ ame, "lo")       │ .c               │ k.c:<global>    │                  │            │                │                 │   "name": "strcp │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "code": "strcp │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 8,    │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 227400   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# ├─────────────┼──────────────────┼──────────────────┼─────────────────┼──────────────────┼────────────┼────────────────┼─────────────────┼──────────────────┼──────────┼───────────┤
# │ <global>    │ strcpy(ifname,   │ src/inet.c       │ src/inet.c:<glo │ get_peer_iface   │       3318 │ <global>       │ get_peer_iface  │ {                │ LOCATION │ CALL      │
# │             │ ifa->ifa_name)   │                  │ bal>            │                  │            │                │                 │   "name": "strcp │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "signature": " │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "code": "strcp │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "typeFullName" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "columnNumber" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "order": 1,    │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "methodFullNam │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "_label": "CAL │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "argumentIndex │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dynamicTypeHi │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "dispatchType" │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "lineNumber":  │          │           │
# │             │                  │                  │                 │                  │            │                │                 │   "id": 258514   │          │           │
# │             │                  │                  │                 │                  │            │                │                 │ }                │          │           │
# └─────────────┴──────────────────┴──────────────────┴─────────────────┴──────────────────┴────────────┴────────────────┴─────────────────┴──────────────────┴──────────┴───────────┘

# %% [markdown]
# ## Detect malloc memcpy overflow
#
# Dangerous copy-operation into heap-allocated buffer.

# %%
async def malloc_overflow():
    connection = await client.get(joern_host, cpggen_host, joern_username, joern_password)
    res = await client.p(connection, """
        ({val src =
            cpg.method(".*malloc$").callIn.where(_.argument(1).arithmetic).l

            cpg.method("(?i)memcpy").callIn.l.filter { memcpyCall =>
            memcpyCall
                .argument(1)
                .reachableBy(src)
                .where(_.inAssignment.target.codeExact(memcpyCall.argument(1).code))
                .whereNot(_.argument(1).codeExact(memcpyCall.argument(3).code))
                .hasNext
        }}).location.toJsonPretty
    """, title="Malloc memcpy overflow problems")
asyncio.run(malloc_overflow())
# Out:
# ╭──────────────────────────────────── CPGQL Query ─────────────────────────────────────╮
# │                                                                                      │
# │         ({val src =                                                                  │
# │             cpg.method(".*malloc$").callIn.where(_.argument(1).arithmetic).l         │
# │                                                                                      │
# │             cpg.method("(?i)memcpy").callIn.l.filter { memcpyCall =>                 │
# │             memcpyCall                                                               │
# │                 .argument(1)                                                         │
# │                 .reachableBy(src)                                                    │
# │                 .where(_.inAssignment.target.codeExact(memcpyCall.argument(1).code)) │
# │                 .whereNot(_.argument(1).codeExact(memcpyCall.argument(3).code))      │
# │                 .hasNext                                                             │
# │         }}).location.toJsonPretty                                                    │
# │                                                                                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────╯
#                                                                           Malloc memcpy overflow problems
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ packageName ┃ symbol           ┃ filename         ┃ className        ┃ methodFullName  ┃ lineNumber ┃ classShortName ┃ methodShortName  ┃ node            ┃ _label   ┃ nodeLabel ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━┩
# │ <global>    │ memcpy(interface │ gsupplicant/supp │ gsupplicant/supp │ store_network_i │        439 │ <global>       │ store_network_in │ {               │ LOCATION │ CALL      │
# │             │ ->network_info.s │ licant.c         │ licant.c:<global │ nformation      │            │                │ formation        │   "name": "memc │          │           │
# │             │ sid, ssid->ssid, │                  │ >                │                 │            │                │                  │   "signature":  │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "code": "memc │          │           │
# │             │         ssid->ss │                  │                  │                 │            │                │                  │   "typeFullName │          │           │
# │             │ id_len)          │                  │                  │                 │            │                │                  │   "columnNumber │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "order": 1,   │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "methodFullNa │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "_label": "CA │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "argumentInde │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "dynamicTypeH │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "dispatchType │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "lineNumber": │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "id": 26672   │          │           │
# │             │                  │                  │                  │                 │            │                │                  │ }               │          │           │
# ├─────────────┼──────────────────┼──────────────────┼──────────────────┼─────────────────┼────────────┼────────────────┼──────────────────┼─────────────────┼──────────┼───────────┤
# │ <global>    │ memcpy(dest,     │ gdhcp/client.c   │ gdhcp/client.c:< │ malloc_option_v │       1877 │ <global>       │ malloc_option_va │ {               │ LOCATION │ CALL      │
# │             │ option, len)     │                  │ global>          │ alue_string     │            │                │ lue_string       │   "name": "memc │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "signature":  │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "code": "memc │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "typeFullName │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "columnNumber │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "order": 13,  │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "methodFullNa │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "_label": "CA │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "argumentInde │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "dynamicTypeH │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "dispatchType │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "lineNumber": │          │           │
# │             │                  │                  │                  │                 │            │                │                  │   "id": 85905   │          │           │
# │             │                  │                  │                  │                 │            │                │                  │ }               │          │           │
# └─────────────┴──────────────────┴──────────────────┴──────────────────┴─────────────────┴────────────┴────────────────┴──────────────────┴─────────────────┴──────────┴───────────┘

# %% [markdown]
# ## Free follows value reuse
#
# A value that is free'd is reused without reassignment. A value is used after being free'd in a path that leads to it without reassignment. Modeled after CVE-2019-18903.

# %%
async def free_reuse():
    connection = await client.get(joern_host, cpggen_host, joern_username, joern_password)
    res = await client.p(connection, """
        ({cpg.method
            .name("(.*_)?free")
            .filter(_.parameter.size == 1)
            .callIn
            .where(_.argument(1).isIdentifier)
            .flatMap(f => {
                val freedIdentifierCode = f.argument(1).code
                val postDom             = f.postDominatedBy.toSetImmutable

                val assignedPostDom = postDom.isIdentifier
                .where(_.inAssignment)
                .codeExact(freedIdentifierCode)
                .flatMap(id => id ++ id.postDominatedBy)

                postDom
                .removedAll(assignedPostDom)
                .isIdentifier
                .codeExact(freedIdentifierCode)
            })}).location.toJsonPretty
    """, title="Free follows reuse problems")
asyncio.run(free_reuse())
# Out:
# ╭─────────────────────────────── CPGQL Query ────────────────────────────────╮
# │                                                                            │
# │         ({cpg.method                                                       │
# │             .name("(.*_)?free")                                            │
# │             .filter(_.parameter.size == 1)                                 │
# │             .callIn                                                        │
# │             .where(_.argument(1).isIdentifier)                             │
# │             .flatMap(f => {                                                │
# │                 val freedIdentifierCode = f.argument(1).code               │
# │                 val postDom             = f.postDominatedBy.toSetImmutable │
# │                                                                            │
# │                 val assignedPostDom = postDom.isIdentifier                 │
# │                 .where(_.inAssignment)                                     │
# │                 .codeExact(freedIdentifierCode)                            │
# │                 .flatMap(id => id ++ id.postDominatedBy)                   │
# │                                                                            │
# │                 postDom                                                    │
# │                 .removedAll(assignedPostDom)                               │
# │                 .isIdentifier                                              │
# │                 .codeExact(freedIdentifierCode)                            │
# │             })}).location.toJsonPretty                                     │
# │                                                                            │
# ╰────────────────────────────────────────────────────────────────────────────╯
#                                                                             Free follows reuse problems
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ packageName ┃ symbol    ┃ filename          ┃ className         ┃ methodFullName    ┃ lineNumber ┃ classShortName ┃ methodShortName  ┃ node              ┃ _label   ┃ nodeLabel  ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ <global>    │ dhcp      │ src/dhcpv6.c      │ src/dhcpv6.c:<glo │ dhcpv6_release    │       1555 │ <global>       │ dhcpv6_release   │ {                 │ LOCATION │ IDENTIFIER │
# │             │           │                   │ bal>              │                   │            │                │                  │   "dynamicTypeHin │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "name": "dhcp", │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "code": "dhcp", │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "typeFullName": │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "columnNumber": │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "order": 1,     │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "_label": "IDEN │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "argumentIndex" │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "lineNumber": 1 │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "id": 267465    │          │            │
# │             │           │                   │                   │                   │            │                │                  │ }                 │          │            │
# ├─────────────┼───────────┼───────────────────┼───────────────────┼───────────────────┼────────────┼────────────────┼──────────────────┼───────────────────┼──────────┼────────────┤
# │ <global>    │ info      │ plugins/wifi.c    │ plugins/wifi.c:<g │ sta_remove_callba │       3365 │ <global>       │ sta_remove_callb │ {                 │ LOCATION │ IDENTIFIER │
# │             │           │                   │ lobal>            │ ck                │            │                │ ack              │   "dynamicTypeHin │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "name": "info", │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "code": "info", │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "typeFullName": │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "columnNumber": │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "order": 1,     │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "_label": "IDEN │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "argumentIndex" │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "lineNumber": 3 │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "id": 50506     │          │            │
# │             │           │                   │                   │                   │            │                │                  │ }                 │          │            │
# ├─────────────┼───────────┼───────────────────┼───────────────────┼───────────────────┼────────────┼────────────────┼──────────────────┼───────────────────┼──────────┼────────────┤
# │ <global>    │ conf_file │ vpn/plugins/l2tp. │ vpn/plugins/l2tp. │ l2tp_died         │        480 │ <global>       │ l2tp_died        │ {                 │ LOCATION │ IDENTIFIER │
# │             │           │ c                 │ c:<global>        │                   │            │                │                  │   "dynamicTypeHin │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "name": "conf_f │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "code": "conf_f │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "typeFullName": │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "columnNumber": │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "order": 1,     │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "_label": "IDEN │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "argumentIndex" │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "lineNumber": 4 │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "id": 75526     │          │            │
# │             │           │                   │                   │                   │            │                │                  │ }                 │          │            │
# ├─────────────┼───────────┼───────────────────┼───────────────────┼───────────────────┼────────────┼────────────────┼──────────────────┼───────────────────┼──────────┼────────────┤
# │ <global>    │ conf_file │ vpn/plugins/l2tp. │ vpn/plugins/l2tp. │ l2tp_died         │        481 │ <global>       │ l2tp_died        │ {                 │ LOCATION │ IDENTIFIER │
# │             │           │ c                 │ c:<global>        │                   │            │                │                  │   "dynamicTypeHin │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "name": "conf_f │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "code": "conf_f │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "typeFullName": │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "columnNumber": │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "order": 1,     │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "_label": "IDEN │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "argumentIndex" │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "lineNumber": 4 │          │            │
# │             │           │                   │                   │                   │            │                │                  │   "id": 75528     │          │            │
# │             │           │                   │                   │                   │            │                │                  │ }                 │          │            │
# └─────────────┴───────────┴───────────────────┴───────────────────┴───────────────────┴────────────┴────────────────┴──────────────────┴───────────────────┴──────────┴────────────┘

# %% [markdown]
# ## Just show me the CVE!!
#
# Source: Parameter to the method `tcp_server_event`
# Sink: Argument from the call `strncpy`

# %%
async def find_reachable_flows():
    connection = await client.get(joern_host, cpggen_host, joern_username, joern_password)
    await client.df(connection, 'cpg.method(".*tcp_server_event.*").parameter', 'cpg.call(".*strncpy.*").argument')
asyncio.run(find_reachable_flows())
# Out:
# ╭─────────────────────── CPGQL Query ───────────────────────╮
# │ def source = cpg.method(".*tcp_server_event.*").parameter │
# ╰───────────────────────────────────────────────────────────╯
# ╭──────────────── CPGQL Query ────────────────╮
# │ def sink = cpg.call(".*strncpy.*").argument │
# ╰─────────────────────────────────────────────╯
# ╭────────────────────────────────── CPGQL Query ──────────────────────────────────╮
# │ sink.reachableByFlows(source).map(m => (m, m.elements.location.l)).toJsonPretty │
# ╰─────────────────────────────────────────────────────────────────────────────────╯
# ╭─ Tainted Identifiers ─╮
# │ channel               │
# │ sk                    │
# │ reply_len_buf         │
# │ reply_len             │
# │ bytes_recv            │
# │ domain_len            │
# │ ptr                   │
# │ uptr                  │
# │ answers               │
# │ uncompressed          │
# │ end                   │
# │ pos                   │
# │ uncomp_len            │
# ╰───────────────────────╯
# ╭─────────────────────────────────────────────────────────────────── Data Flow ───────────────────────────────────────────────────────────────────╮
# │ src/dnsproxy.c:2253 tcp_server_event() GIOChannel *channel                                                                                      │
# │ ├── src/dnsproxy.c:2259 tcp_server_event() g_io_channel_unix_get_fd(channel )                                                                   │
# │ ├── src/dnsproxy.c:2402 tcp_server_event() reply_len_buf[0]                                                                                     │
# │ ├── src/dnsproxy.c:2402 tcp_server_event() reply_len_buf[0] << 8                                                                                │
# │ ├── src/dnsproxy.c:2402 tcp_server_event() reply_len_buf[1]                                                                                     │
# │ ├── src/dnsproxy.c:2402 tcp_server_event() reply_len_buf[1] | reply_len_buf[0] << 8                                                             │
# │ ├── src/dnsproxy.c:2411 tcp_server_event() reply->len                                                                                           │
# │ ├── src/dnsproxy.c:2419 tcp_server_event() reply->received                                                                                      │
# │ ├── src/dnsproxy.c:2419 tcp_server_event() reply->len - reply->received                                                                         │
# │ ├── src/dnsproxy.c:2418 tcp_server_event() reply->buf + reply->received                                                                         │
# │ ├── src/dnsproxy.c:2418 tcp_server_event() recv(sk, reply->buf + reply->received, reply->len - reply->received, 0)                              │
# │ ├── src/dnsproxy.c:2431 tcp_server_event() reply->received                                                                                      │
# │ ├── src/dnsproxy.c:1935 forward_dns_reply() int reply_len                                                                                       │
# │ ├── src/dnsproxy.c:1995 forward_dns_reply() reply_len - header_len                                                                              │
# │ ├── src/dnsproxy.c:1994 forward_dns_reply() ptr + 1 + host_len                                                                                  │
# │ ├── src/dnsproxy.c:1994 forward_dns_reply() strnlen(ptr + 1 + host_len, reply_len - header_len)                                                 │
# │ ├── src/dnsproxy.c:2046 forward_dns_reply() len + domain_len + 1                                                                                │
# │ ├── src/dnsproxy.c:1766 uncompress() char *uncompressed                                                                                         │
# │ ├── src/dnsproxy.c:1807 uncompress() uptr[0]                                                                                                    │
# │ ├── src/dnsproxy.c:2065 forward_dns_reply() uncompress(ntohs(hdr->ancount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr) │
# │ ├── src/dnsproxy.c:1766 uncompress() char *ptr                                                                                                  │
# │ ├── src/dnsproxy.c:1836 uncompress() ptr + dlen                                                                                                 │
# │ ├── src/dnsproxy.c:1733 convert_label() char *end                                                                                               │
# │ ├── src/dnsproxy.c:1739 convert_label() (u_char *)end                                                                                           │
# │ ├── src/dnsproxy.c:1739 convert_label() dn_expand((u_char *)start, (u_char *)end, (u_char *)ptr, name, NS_MAXLABEL)                             │
# │ ├── src/dnsproxy.c:1756 convert_label() *used_comp                                                                                              │
# │ ├── src/dnsproxy.c:1782 uncompress() &pos                                                                                                       │
# │ ├── src/dnsproxy.c:1733 convert_label() char *ptr                                                                                               │
# │ ├── src/dnsproxy.c:1851 uncompress() uptr - uncompressed                                                                                        │
# │ └── src/dnsproxy.c:1791 uncompress() uncomp_len - (uptr - uncompressed)                                                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# ╭─ Tainted Identifiers ─╮
# │ channel               │
# │ sk                    │
# │ reply_len_buf         │
# │ reply_len             │
# │ bytes_recv            │
# │ domain_len            │
# │ ptr                   │
# │ uptr                  │
# │ answers               │
# │ uncompressed          │
# │ uncompressed_ptr      │
# │ domain                │
# │ end                   │
# │ new_len               │
# │ new_reply             │
# │ reply                 │
# │ msg                   │
# │ buf                   │
# ╰───────────────────────╯
# ╭──────────────────────────────────────────────────── Data Flow ─────────────────────────────────────────────────────╮
# │ src/dnsproxy.c:2253 tcp_server_event() GIOChannel *channel                                                         │
# │ ├── src/dnsproxy.c:2259 tcp_server_event() g_io_channel_unix_get_fd(channel )                                      │
# │ ├── src/dnsproxy.c:2402 tcp_server_event() reply_len_buf[0]                                                        │
# │ ├── src/dnsproxy.c:2402 tcp_server_event() reply_len_buf[0] << 8                                                   │
# │ ├── src/dnsproxy.c:2402 tcp_server_event() reply_len_buf[1]                                                        │
# │ ├── src/dnsproxy.c:2402 tcp_server_event() reply_len_buf[1] | reply_len_buf[0] << 8                                │
# │ ├── src/dnsproxy.c:2411 tcp_server_event() reply->len                                                              │
# │ ├── src/dnsproxy.c:2419 tcp_server_event() reply->received                                                         │
# │ ├── src/dnsproxy.c:2419 tcp_server_event() reply->len - reply->received                                            │
# │ ├── src/dnsproxy.c:2418 tcp_server_event() reply->buf + reply->received                                            │
# │ ├── src/dnsproxy.c:2418 tcp_server_event() recv(sk, reply->buf + reply->received, reply->len - reply->received, 0) │
# │ ├── src/dnsproxy.c:2431 tcp_server_event() reply->received                                                         │
# │ ├── src/dnsproxy.c:1935 forward_dns_reply() int reply_len                                                          │
# │ ├── src/dnsproxy.c:1995 forward_dns_reply() reply_len - header_len                                                 │
# │ ├── src/dnsproxy.c:1994 forward_dns_reply() ptr + 1 + host_len                                                     │
# │ ├── src/dnsproxy.c:1994 forward_dns_reply() strnlen(ptr + 1 + host_len, reply_len - header_len)                    │
# │ ├── src/dnsproxy.c:2046 forward_dns_reply() len + domain_len + 1                                                   │
# │ ├── src/dnsproxy.c:1766 uncompress() char *uncompressed                                                            │
# │ ├── src/dnsproxy.c:1807 uncompress() uptr[0]                                                                       │
# │ ├── src/dnsproxy.c:1887 uncompress() *uncompressed_ptr                                                             │
# │ ├── src/dnsproxy.c:2068 forward_dns_reply() &uptr                                                                  │
# │ ├── src/dnsproxy.c:1767 uncompress() char **uncompressed_ptr                                                       │
# │ ├── src/dnsproxy.c:2075 forward_dns_reply() &uptr                                                                  │
# │ ├── src/dnsproxy.c:1896 strip_domains() char *answers                                                              │
# │ ├── src/dnsproxy.c:1903 strip_domains() strstr( answers , name)                                                    │
# │ ├── src/dnsproxy.c:1905 strip_domains() ptr + name_len                                                             │
# │ ├── src/dnsproxy.c:1908 strip_domains() strlen(domain )                                                            │
# │ ├── src/dnsproxy.c:1912 strip_domains() domain + domain_len                                                        │
# │ ├── src/dnsproxy.c:1932 strip_domains() end - start                                                                │
# │ ├── src/dnsproxy.c:2096 forward_dns_reply() strip_domains(uncompressed, answers, uptr - answers)                   │
# │ ├── src/dnsproxy.c:2109 forward_dns_reply() header_len + new_len + fixed_len                                       │
# │ ├── src/dnsproxy.c:2111 forward_dns_reply() g_try_malloc(reply_len)                                                │
# │ ├── src/dnsproxy.c:1383 cache_update() unsigned char *msg                                                          │
# │ ├── src/dnsproxy.c:1429 cache_update() msg + offset                                                                │
# │ ├── src/dnsproxy.c:977 parse_response() unsigned char *buf                                                         │
# │ ├── src/dnsproxy.c:1004 parse_response() buf + sizeof(struct domain_hdr)                                           │
# │ └── src/dnsproxy.c:1006 parse_response() (char *) ptr                                                              │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# ╭─ Tainted Identifiers ─╮
# │ channel               │
# │ sk                    │
# │ reply_len_buf         │
# │ reply_len             │
# │ bytes_recv            │
# │ domain_len            │
# │ ptr                   │
# │ uptr                  │
# │ answers               │
# │ uncompressed          │
# │ end                   │
# │ pos                   │
# │ name                  │
# │ comp_pos              │
# ╰───────────────────────╯
# ╭─────────────────────────────────────────────────────────────────── Data Flow ───────────────────────────────────────────────────────────────────╮
# │ src/dnsproxy.c:2253 tcp_server_event() GIOChannel *channel                                                                                      │
# │ ├── src/dnsproxy.c:2259 tcp_server_event() g_io_channel_unix_get_fd(channel )                                                                   │
# │ ├── src/dnsproxy.c:2402 tcp_server_event() reply_len_buf[0]                                                                                     │
# │ ├── src/dnsproxy.c:2402 tcp_server_event() reply_len_buf[0] << 8                                                                                │
# │ ├── src/dnsproxy.c:2402 tcp_server_event() reply_len_buf[1]                                                                                     │
# │ ├── src/dnsproxy.c:2402 tcp_server_event() reply_len_buf[1] | reply_len_buf[0] << 8                                                             │
# │ ├── src/dnsproxy.c:2411 tcp_server_event() reply->len                                                                                           │
# │ ├── src/dnsproxy.c:2419 tcp_server_event() reply->received                                                                                      │
# │ ├── src/dnsproxy.c:2419 tcp_server_event() reply->len - reply->received                                                                         │
# │ ├── src/dnsproxy.c:2418 tcp_server_event() reply->buf + reply->received                                                                         │
# │ ├── src/dnsproxy.c:2418 tcp_server_event() recv(sk, reply->buf + reply->received, reply->len - reply->received, 0)                              │
# │ ├── src/dnsproxy.c:2431 tcp_server_event() reply->received                                                                                      │
# │ ├── src/dnsproxy.c:1935 forward_dns_reply() int reply_len                                                                                       │
# │ ├── src/dnsproxy.c:1995 forward_dns_reply() reply_len - header_len                                                                              │
# │ ├── src/dnsproxy.c:1994 forward_dns_reply() ptr + 1 + host_len                                                                                  │
# │ ├── src/dnsproxy.c:1994 forward_dns_reply() strnlen(ptr + 1 + host_len, reply_len - header_len)                                                 │
# │ ├── src/dnsproxy.c:2046 forward_dns_reply() len + domain_len + 1                                                                                │
# │ ├── src/dnsproxy.c:1766 uncompress() char *uncompressed                                                                                         │
# │ ├── src/dnsproxy.c:1807 uncompress() uptr[0]                                                                                                    │
# │ ├── src/dnsproxy.c:2065 forward_dns_reply() uncompress(ntohs(hdr->ancount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr) │
# │ ├── src/dnsproxy.c:1766 uncompress() char *ptr                                                                                                  │
# │ ├── src/dnsproxy.c:1836 uncompress() ptr + dlen                                                                                                 │
# │ ├── src/dnsproxy.c:1733 convert_label() char *end                                                                                               │
# │ ├── src/dnsproxy.c:1739 convert_label() (u_char *)end                                                                                           │
# │ ├── src/dnsproxy.c:1739 convert_label() dn_expand((u_char *)start, (u_char *)end, (u_char *)ptr, name, NS_MAXLABEL)                             │
# │ ├── src/dnsproxy.c:1756 convert_label() *used_comp                                                                                              │
# │ ├── src/dnsproxy.c:1782 uncompress() &pos                                                                                                       │
# │ ├── src/dnsproxy.c:1733 convert_label() char *ptr                                                                                               │
# │ ├── src/dnsproxy.c:1739 convert_label() (u_char *)ptr                                                                                           │
# │ ├── src/dnsproxy.c:1750 convert_label() dn_comp( name , (u_char *)uptr, remaining_len, NULL, NULL)                                              │
# │ ├── src/dnsproxy.c:1757 convert_label() *used_uncomp                                                                                            │
# │ ├── src/dnsproxy.c:1863 uncompress() &comp_pos                                                                                                  │
# │ ├── src/dnsproxy.c:1828 uncompress() comp_pos & 0xff                                                                                            │
# │ ├── src/dnsproxy.c:1828 uncompress() uptr[-1]                                                                                                   │
# │ └── src/dnsproxy.c:1834 uncompress() uptr[-2]                                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
