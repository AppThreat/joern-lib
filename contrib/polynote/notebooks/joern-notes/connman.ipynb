# %% [markdown]
# # connman
#
# A vulnerability in connman was used to hack a [Tesla Model X](https://youtu.be/krSj81thN0w?t=2183). The vulnerability was found using fuzzing. The goal of this exercise is to find such vulnerabilities statically.
#
# We begin by setting up the basics for joern.

# %%
import asyncio

from joern_lib import client, workspace
from joern_lib.detectors import common as cpg, c
from joern_lib.utils import print_table

joern_host = "http://joern:9000"
joern_username = "admin"
joern_password  = "admin"

# %% [markdown]
# ## Clone the vulnerable repo
#
# We clone the vulnerable [repo](https://github.com/helium/connman) using GitPython and importing to joern using import_code api.

# %%
import git
import os

if not os.path.exists("/tmp/connman"):
    try:
        git.Repo.clone_from("https://github.com/helium/connman", "/tmp/connman", branch="master", depth=1)
    except Exception as e:
        print(e)
else:
    print("/tmp/connman already exists")
# Out:
# /tmp/connman already exists

# %%
async def create_workspace():
    connection = await client.get(joern_host, joern_username, joern_password)
    res = await workspace.import_code(connection, "/tmp/connman", "connman");
    print (res)
asyncio.run(create_workspace())
# Out:
# True

# %% [markdown]
# ## Practice with C detectors
#
# Joern lib has a detector module with predefined queries for common use cases.

# %%
async def test_detectors_fn():
    connection = await client.get(joern_host, joern_username, joern_password)
    res = await cpg.get_complex_functions(connection, n=10)
    print_table (res, title="Complex Functions in code")
    res = await cpg.get_too_many_loops_functions(connection, n=10)
    print_table (res, title="Too Many Loops Functions in code")
    res = await cpg.get_too_nested_functions(connection, n=6)
    print_table (res, title="Too Nested Functions in code")
asyncio.run(test_detectors_fn())
# Out:
#                                                                                                                                Complex Functions in code
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ node                                ┃ symbol                              ┃ packageName ┃ nodeLabel ┃ methodShortName                     ┃ methodFullName                      ┃ lineNumber ┃ filename                       ┃ classShortName ┃ className                           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ {'name': 'set_connected',           │ set_connected                       │ <global>    │ METHOD    │ set_connected                       │ set_connected                       │        306 │ plugins/ofono.c                │ <global>       │ plugins/ofono.c:<global>            │
# │ 'astParentFullName':                │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'plugins/ofono.c:<global>',         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumberEnd': 1, 'fullName':   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'set_connected', 'signature': 'void │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ set_connected                       │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ (modem_data*,network_context*)',    │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'astParentType': 'TYPE_DECL',       │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumber': 1, 'lineNumberEnd': │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 371, '_label': 'METHOD', 'code':    │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'void set_connected (struct         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ modem_data *modem,struct            │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ network_context *context)',         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'isExternal': False, 'lineNumber':  │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 306, 'id': 946, 'order': 14,        │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'filename': 'plugins/ofono.c'}      │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# ├─────────────────────────────────────┼─────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────────┼─────────────────────────────────────┼────────────┼────────────────────────────────┼────────────────┼─────────────────────────────────────┤
# │ {'name': 'extract_ipv4_settings',   │ extract_ipv4_settings               │ <global>    │ METHOD    │ extract_ipv4_settings               │ extract_ipv4_settings               │        833 │ plugins/ofono.c                │ <global>       │ plugins/ofono.c:<global>            │
# │ 'astParentFullName':                │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'plugins/ofono.c:<global>',         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumberEnd': 1, 'fullName':   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'extract_ipv4_settings',            │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'signature': 'void                  │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ extract_ipv4_settings               │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ (DBusMessageIter*,network_context*) │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ ', 'astParentType': 'TYPE_DECL',    │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumber': 1, 'lineNumberEnd': │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 932, '_label': 'METHOD', 'code':    │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'void extract_ipv4_settings         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ (DBusMessageIter *array,struct      │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ network_context *context)',         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'isExternal': False, 'lineNumber':  │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 833, 'id': 2157, 'order': 34,       │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'filename': 'plugins/ofono.c'}      │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# ├─────────────────────────────────────┼─────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────────┼─────────────────────────────────────┼────────────┼────────────────────────────────┼────────────────┼─────────────────────────────────────┤
# │ {'name': 'extract_ipv6_settings',   │ extract_ipv6_settings               │ <global>    │ METHOD    │ extract_ipv6_settings               │ extract_ipv6_settings               │        934 │ plugins/ofono.c                │ <global>       │ plugins/ofono.c:<global>            │
# │ 'astParentFullName':                │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'plugins/ofono.c:<global>',         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumberEnd': 1, 'fullName':   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'extract_ipv6_settings',            │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'signature': 'void                  │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ extract_ipv6_settings               │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ (DBusMessageIter*,network_context*) │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ ', 'astParentType': 'TYPE_DECL',    │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumber': 1, 'lineNumberEnd': │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 1018, '_label': 'METHOD', 'code':   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'void extract_ipv6_settings         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ (DBusMessageIter *array,struct      │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ network_context *context)',         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'isExternal': False, 'lineNumber':  │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 934, 'id': 2444, 'order': 35,       │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'filename': 'plugins/ofono.c'}      │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# ├─────────────────────────────────────┼─────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────────┼─────────────────────────────────────┼────────────┼────────────────────────────────┼────────────────┼─────────────────────────────────────┤
# │ {'name': 'add_cm_context',          │ add_cm_context                      │ <global>    │ METHOD    │ add_cm_context                      │ add_cm_context                      │       1195 │ plugins/ofono.c                │ <global>       │ plugins/ofono.c:<global>            │
# │ 'astParentFullName':                │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'plugins/ofono.c:<global>',         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumberEnd': 1, 'fullName':   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'add_cm_context', 'signature': 'int │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ add_cm_context                      │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ (modem_data*,char*,DBusMessageIter* │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ )', 'astParentType': 'TYPE_DECL',   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumber': 1, 'lineNumberEnd': │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 1275, '_label': 'METHOD', 'code':   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'int add_cm_context (struct         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ modem_data *modem,const char        │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ *context_path,DBusMessageIter       │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ *dict)', 'isExternal': False,       │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'lineNumber': 1195, 'id': 3121,     │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'order': 42, 'filename':            │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'plugins/ofono.c'}                  │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# ├─────────────────────────────────────┼─────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────────┼─────────────────────────────────────┼────────────┼────────────────────────────────┼────────────────┼─────────────────────────────────────┤
# │ {'name': 'context_changed',         │ context_changed                     │ <global>    │ METHOD    │ context_changed                     │ context_changed                     │       1327 │ plugins/ofono.c                │ <global>       │ plugins/ofono.c:<global>            │
# │ 'astParentFullName':                │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'plugins/ofono.c:<global>',         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumberEnd': 1, 'fullName':   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'context_changed', 'signature':     │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'gboolean context_changed           │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ (DBusConnection*,DBusMessage*,void* │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ )', 'astParentType': 'TYPE_DECL',   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumber': 1, 'lineNumberEnd': │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 1423, '_label': 'METHOD', 'code':   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'gboolean context_changed           │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ (DBusConnection *conn,DBusMessage   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ *message,void *user_data)',         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'isExternal': False, 'lineNumber':  │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 1327, 'id': 3500, 'order': 46,      │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'filename': 'plugins/ofono.c'}      │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# ├─────────────────────────────────────┼─────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────────┼─────────────────────────────────────┼────────────┼────────────────────────────────┼────────────────┼─────────────────────────────────────┤
# │ {'name': 'netreg_properties_reply', │ netreg_properties_reply             │ <global>    │ METHOD    │ netreg_properties_reply             │ netreg_properties_reply             │       1762 │ plugins/ofono.c                │ <global>       │ plugins/ofono.c:<global>            │
# │ 'astParentFullName':                │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'plugins/ofono.c:<global>',         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumberEnd': 1, 'fullName':   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'netreg_properties_reply',          │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'signature': 'void                  │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ netreg_properties_reply             │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ (modem_data*,DBusMessageIter*)',    │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'astParentType': 'TYPE_DECL',       │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumber': 1, 'lineNumberEnd': │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 1811, '_label': 'METHOD', 'code':   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'void netreg_properties_reply       │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ (struct modem_data                  │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ *modem,DBusMessageIter *dict)',     │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'isExternal': False, 'lineNumber':  │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 1762, 'id': 4536, 'order': 57,      │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'filename': 'plugins/ofono.c'}      │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# ├─────────────────────────────────────┼─────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────────┼─────────────────────────────────────┼────────────┼────────────────────────────────┼────────────────┼─────────────────────────────────────┤
# │ {'name': 'cdma_netreg_changed',     │ cdma_netreg_changed                 │ <global>    │ METHOD    │ cdma_netreg_changed                 │ cdma_netreg_changed                 │       1846 │ plugins/ofono.c                │ <global>       │ plugins/ofono.c:<global>            │
# │ 'astParentFullName':                │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'plugins/ofono.c:<global>',         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumberEnd': 1, 'fullName':   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'cdma_netreg_changed', 'signature': │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'gboolean cdma_netreg_changed       │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ (DBusConnection*,DBusMessage*,void* │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ )', 'astParentType': 'TYPE_DECL',   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumber': 1, 'lineNumberEnd': │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 1887, '_label': 'METHOD', 'code':   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'gboolean cdma_netreg_changed       │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ (DBusConnection *conn,DBusMessage   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ *message,void *user_data)',         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'isExternal': False, 'lineNumber':  │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 1846, 'id': 4748, 'order': 60,      │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'filename': 'plugins/ofono.c'}      │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# ├─────────────────────────────────────┼─────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────────┼─────────────────────────────────────┼────────────┼────────────────────────────────┼────────────────┼─────────────────────────────────────┤
# │ {'name': 'modem_update_interfaces', │ modem_update_interfaces             │ <global>    │ METHOD    │ modem_update_interfaces             │ modem_update_interfaces             │       2253 │ plugins/ofono.c                │ <global>       │ plugins/ofono.c:<global>            │
# │ 'astParentFullName':                │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'plugins/ofono.c:<global>',         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumberEnd': 1, 'fullName':   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'modem_update_interfaces',          │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'signature': 'void                  │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ modem_update_interfaces             │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ (modem_data*,uint8_t,uint8_t)',     │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'astParentType': 'TYPE_DECL',       │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumber': 1, 'lineNumberEnd': │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 2314, '_label': 'METHOD', 'code':   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'void modem_update_interfaces       │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ (struct modem_data *modem,uint8_t   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ old_ifaces,uint8_t new_ifaces)',    │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'isExternal': False, 'lineNumber':  │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 2253, 'id': 5672, 'order': 79,      │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'filename': 'plugins/ofono.c'}      │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# ├─────────────────────────────────────┼─────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────────┼─────────────────────────────────────┼────────────┼────────────────────────────────┼────────────────┼─────────────────────────────────────┤
# │ {'name': 'modem_changed',           │ modem_changed                       │ <global>    │ METHOD    │ modem_changed                       │ modem_changed                       │       2316 │ plugins/ofono.c                │ <global>       │ plugins/ofono.c:<global>            │
# │ 'astParentFullName':                │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'plugins/ofono.c:<global>',         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumberEnd': 1, 'fullName':   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'modem_changed', 'signature':       │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'gboolean modem_changed             │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ (DBusConnection*,DBusMessage*,void* │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ )', 'astParentType': 'TYPE_DECL',   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumber': 1, 'lineNumberEnd': │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 2395, '_label': 'METHOD', 'code':   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'gboolean modem_changed             │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ (DBusConnection *conn,DBusMessage   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ *message,void *user_data)',         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'isExternal': False, 'lineNumber':  │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 2316, 'id': 5817, 'order': 80,      │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'filename': 'plugins/ofono.c'}      │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# ├─────────────────────────────────────┼─────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────────┼─────────────────────────────────────┼────────────┼────────────────────────────────┼────────────────┼─────────────────────────────────────┤
# │ {'name': 'add_modem',               │ add_modem                           │ <global>    │ METHOD    │ add_modem                           │ add_modem                           │       2397 │ plugins/ofono.c                │ <global>       │ plugins/ofono.c:<global>            │
# │ 'astParentFullName':                │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'plugins/ofono.c:<global>',         │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'columnNumberEnd': 1, 'fullName':   │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'add_modem', 'signature': 'void     │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ add_modem                           │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ (char*,DBusMessageIter*)',          │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# │ 'astParentType': 'TYPE_DECL',       │                                     │             │           │                                     │                                     │            │                                │                │                                     │
# ...
# │ {'name': 'interface_property',      │ interface_property                  │ <global>    │ METHOD    │ interface_property                   │ interface_property                  │       1097 │ tools/supplicant.c           │ <global>       │ tools/supplicant.c:<global>          │
# │ 'astParentFullName':                │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'tools/supplicant.c:<global>',      │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'columnNumberEnd': 2, 'fullName':   │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'interface_property', 'signature':  │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'void interface_property            │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ (char*,DBusMessageIter*,void*)',    │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'astParentType': 'TYPE_DECL',       │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'columnNumber': 1, 'lineNumberEnd': │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 1186, '_label': 'METHOD', 'code':   │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'void interface_property (const     │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ char *key,DBusMessageIter           │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ *iter,void *user_data)',            │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'isExternal': False, 'lineNumber':  │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 1097, 'id': 274156, 'order': 93,    │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'filename': 'tools/supplicant.c'}   │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# ├─────────────────────────────────────┼─────────────────────────────────────┼─────────────┼───────────┼──────────────────────────────────────┼─────────────────────────────────────┼────────────┼──────────────────────────────┼────────────────┼──────────────────────────────────────┤
# │ {'name': 'service_property',        │ service_property                    │ <global>    │ METHOD    │ service_property                     │ service_property                    │       1271 │ tools/supplicant.c           │ <global>       │ tools/supplicant.c:<global>          │
# │ 'astParentFullName':                │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'tools/supplicant.c:<global>',      │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'columnNumberEnd': 2, 'fullName':   │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'service_property', 'signature':    │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'void service_property              │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ (char*,DBusMessageIter*,void*)',    │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'astParentType': 'TYPE_DECL',       │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'columnNumber': 1, 'lineNumberEnd': │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 1304, '_label': 'METHOD', 'code':   │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'void service_property (const char  │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ *key,DBusMessageIter *iter,void     │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ *user_data)', 'isExternal': False,  │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'lineNumber': 1271, 'id': 274684,   │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'order': 98, 'filename':            │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'tools/supplicant.c'}               │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# ├─────────────────────────────────────┼─────────────────────────────────────┼─────────────┼───────────┼──────────────────────────────────────┼─────────────────────────────────────┼────────────┼──────────────────────────────┼────────────────┼──────────────────────────────────────┤
# │ {'name': 'notify_update',           │ notify_update                       │ <global>    │ METHOD    │ notify_update                        │ notify_update                       │        106 │ tools/session-api.c          │ <global>       │ tools/session-api.c:<global>         │
# │ 'astParentFullName':                │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'tools/session-api.c:<global>',     │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'columnNumberEnd': 1, 'fullName':   │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'notify_update', 'signature':       │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'DBusMessage notify_update          │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ (DBusConnection*,DBusMessage*,void* │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ )', 'astParentType': 'TYPE_DECL',   │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'columnNumber': 1, 'lineNumberEnd': │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 226, '_label': 'METHOD', 'code':    │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'DBusMessage notify_update          │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ (DBusConnection *conn,DBusMessage   │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ *msg,void *user_data)',             │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'isExternal': False, 'lineNumber':  │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 106, 'id': 277405, 'order': 6,      │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# │ 'filename': 'tools/session-api.c'}  │                                     │             │           │                                      │                                     │            │                              │                │                                      │
# └─────────────────────────────────────┴─────────────────────────────────────┴─────────────┴───────────┴──────────────────────────────────────┴─────────────────────────────────────┴────────────┴──────────────────────────────┴────────────────┴──────────────────────────────────────┘
# Future exception was never retrieved
# future: <Future finished exception=ConnectionClosedError(None, None, None)>
# Traceback (most recent call last):
#   File "/opt/polynote/tmp/joern-notes/connman.ipynb/venv/lib64/python3.9/site-packages/websockets/legacy/protocol.py", line 968, in transfer_data
#     message = await self.read_message()
#   File "/opt/polynote/tmp/joern-notes/connman.ipynb/venv/lib64/python3.9/site-packages/websockets/legacy/protocol.py", line 1038, in read_message
#     frame = await self.read_data_frame(max_size=self.max_size)
#   File "/opt/polynote/tmp/joern-notes/connman.ipynb/venv/lib64/python3.9/site-packages/websockets/legacy/protocol.py", line 1113, in read_data_frame
#     frame = await self.read_frame(max_size)
#   File "/opt/polynote/tmp/joern-notes/connman.ipynb/venv/lib64/python3.9/site-packages/websockets/legacy/protocol.py", line 1170, in read_frame
#     frame = await Frame.read(
#   File "/opt/polynote/tmp/joern-notes/connman.ipynb/venv/lib64/python3.9/site-packages/websockets/legacy/framing.py", line 69, in read
#     data = await reader(2)
#   File "/usr/lib64/python3.9/asyncio/streams.py", line 723, in readexactly
#     await self._wait_for_data('readexactly')
#   File "/usr/lib64/python3.9/asyncio/streams.py", line 517, in _wait_for_data
#     await self._waiter
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# websockets.exceptions.ConnectionClosedError: no close frame received or sent

# %% [markdown]
# ## Detect dangerous string copy functions used
#
# Avoid `strcpy` or `strncpy` function. `strcpy` does not check buffer lengths. A possible mitigation could be `strncpy` which could prevent buffer overflows but does not null-terminate strings leading to memory corruption (Out-of-bounds write). A secure alternative (on BSD) is `strlcpy`.

# %%
async def dangerous_string_fn():
    connection = await client.get(joern_host, joern_username, joern_password)
    res = await c.get_strcpy(connection)
    print_table (res, title="Dangerous string functions usage")
asyncio.run(dangerous_string_fn())
# Out:
#                                                                                                                             Dangerous string functions usage
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ node                                         ┃ symbol                                       ┃ packageName ┃ nodeLabel ┃ methodShortName                 ┃ methodFullName                  ┃ lineNumber ┃ filename                ┃ classShortName ┃ className                        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ {'name': 'strncpy', 'signature': '', 'code': │ strncpy(pathname, basepath, sizeof(pathname) │ <global>    │ CALL      │ find_origin                     │ find_origin                     │        163 │ src/timezone.c          │ <global>       │ src/timezone.c:<global>          │
# │ 'strncpy(pathname, basepath,                 │ - 1)                                         │             │           │                                 │                                 │            │                         │                │                                  │
# │ sizeof(pathname) - 1)', 'typeFullName':      │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '<empty>', 'columnNumber': 3, 'order': 1,    │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strncpy', '_label':       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 163, 'id': 10687}              │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strncpy', 'signature': '', 'code': │ strncpy(pathname, d->d_name,                 │ <global>    │ CALL      │ find_origin                     │ find_origin                     │        209 │ src/timezone.c          │ <global>       │ src/timezone.c:<global>          │
# │ 'strncpy(pathname, d->d_name,                │ sizeof(pathname))                            │             │           │                                 │                                 │            │                         │                │                                  │
# │ sizeof(pathname))', 'typeFullName':          │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '<empty>', 'columnNumber': 5, 'order': 1,    │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strncpy', '_label':       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 209, 'id': 10839}              │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strncpy', 'signature': '', 'code': │ strncpy(dns_name, (char *)&value,            │ <global>    │ CALL      │ get_domains                     │ get_domains                     │       2123 │ gdhcp/client.c          │ <global>       │ gdhcp/client.c:<global>          │
# │ 'strncpy(dns_name, (char *)&value,           │ NS_MAXDNAME)                                 │             │           │                                 │                                 │            │                         │                │                                  │
# │ NS_MAXDNAME)', 'typeFullName': '<empty>',    │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'columnNumber': 3, 'order': 1,               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strncpy', '_label':       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 2123, 'id': 84896}             │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strncpy', 'signature': '', 'code': │ strncpy(ifr.ifr_name, ifname,                │ <global>    │ CALL      │ inet_ifup                       │ inet_ifup                       │         51 │ tools/tap-test.c        │ <global>       │ tools/tap-test.c:<global>        │
# │ 'strncpy(ifr.ifr_name, ifname,               │ sizeof(ifr.ifr_name) - 1)                    │             │           │                                 │                                 │            │                         │                │                                  │
# │ sizeof(ifr.ifr_name) - 1)', 'typeFullName':  │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '<empty>', 'columnNumber': 2, 'order': 7,    │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strncpy', '_label':       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 51, 'id': 117431}              │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strncpy', 'signature': '', 'code': │ strncpy(ifr.ifr_name, ifname,                │ <global>    │ CALL      │ create_tap                      │ create_tap                      │         91 │ tools/tap-test.c        │ <global>       │ tools/tap-test.c:<global>        │
# │ 'strncpy(ifr.ifr_name, ifname,               │ sizeof(ifr.ifr_name) - 1)                    │             │           │                                 │                                 │            │                         │                │                                  │
# │ sizeof(ifr.ifr_name) - 1)', 'typeFullName':  │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '<empty>', 'columnNumber': 2, 'order': 8,    │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strncpy', '_label':       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 91, 'id': 117533}              │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strncpy', 'signature': '', 'code': │ strncpy(wrq.ifr_name, ifname,                │ <global>    │ CALL      │ wext_interface                  │ wext_interface                  │        107 │ src/rtnl.c              │ <global>       │ src/rtnl.c:<global>              │
# │ 'strncpy(wrq.ifr_name, ifname,               │ sizeof(wrq.ifr_name) - 1)                    │             │           │                                 │                                 │            │                         │                │                                  │
# │ sizeof(wrq.ifr_name) - 1)', 'typeFullName':  │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '<empty>', 'columnNumber': 2, 'order': 7,    │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strncpy', '_label':       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 107, 'id': 124624}             │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strncpy', 'signature': '', 'code': │ strncpy(vifr.device1, ifname,                │ <global>    │ CALL      │ get_vlan_vid                    │ get_vlan_vid                    │         76 │ plugins/ethernet.c      │ <global>       │ plugins/ethernet.c:<global>      │
# │ 'strncpy(vifr.device1, ifname,               │ sizeof(vifr.device1))                        │             │           │                                 │                                 │            │                         │                │                                  │
# │ sizeof(vifr.device1))', 'typeFullName':      │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '<empty>', 'columnNumber': 2, 'order': 8,    │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strncpy', '_label':       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 76, 'id': 184619}              │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strncpy', 'signature': '', 'code': │ strncpy(ifr.ifr_name, ifname,                │ <global>    │ CALL      │ get_dsa_port                    │ get_dsa_port                    │        102 │ plugins/ethernet.c      │ <global>       │ plugins/ethernet.c:<global>      │
# │ 'strncpy(ifr.ifr_name, ifname,               │ sizeof(ifr.ifr_name))                        │             │           │                                 │                                 │            │                         │                │                                  │
# │ sizeof(ifr.ifr_name))', 'typeFullName':      │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '<empty>', 'columnNumber': 2, 'order': 11,   │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strncpy', '_label':       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 102, 'id': 184689}             │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strncpy', 'signature': '', 'code': │ strncpy(vifr.device1, ifname,                │ <global>    │ CALL      │ get_dsa_port                    │ get_dsa_port                    │        106 │ plugins/ethernet.c      │ <global>       │ plugins/ethernet.c:<global>      │
# │ 'strncpy(vifr.device1, ifname,               │ sizeof(vifr.device1))                        │             │           │                                 │                                 │            │                         │                │                                  │
# │ sizeof(vifr.device1))', 'typeFullName':      │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '<empty>', 'columnNumber': 2, 'order': 13,   │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strncpy', '_label':       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 106, 'id': 184703}             │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strncpy', 'signature': '', 'code': │ strncpy(ifr.ifr_name, vifr.u.device2,        │ <global>    │ CALL      │ get_dsa_port                    │ get_dsa_port                    │        109 │ plugins/ethernet.c      │ <global>       │ plugins/ethernet.c:<global>      │
# │ 'strncpy(ifr.ifr_name, vifr.u.device2,       │ sizeof(ifr.ifr_name))                        │             │           │                                 │                                 │            │                         │                │                                  │
# │ sizeof(ifr.ifr_name))', 'typeFullName':      │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '<empty>', 'columnNumber': 3, 'order': 1,    │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strncpy', '_label':       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 109, 'id': 184721}             │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strncpy', 'signature': '', 'code': │ strncpy(p.name, "tun6to4", sizeof(p.name) -  │ <global>    │ CALL      │ tunnel_create                   │ tunnel_create                   │         80 │ src/6to4.c              │ <global>       │ src/6to4.c:<global>              │
# │ 'strncpy(p.name, "tun6to4", sizeof(p.name) - │ 1)                                           │             │           │                                 │                                 │            │                         │                │                                  │
# │ 1)', 'typeFullName': '<empty>',              │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'columnNumber': 2, 'order': 13,              │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strncpy', '_label':       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 80, 'id': 187177}              │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strncpy', 'signature': '', 'code': │ strncpy(ifr.ifr_name, "sit0",                │ <global>    │ CALL      │ tunnel_create                   │ tunnel_create                   │         82 │ src/6to4.c              │ <global>       │ src/6to4.c:<global>              │
# │ 'strncpy(ifr.ifr_name, "sit0",               │ sizeof(ifr.ifr_name) - 1)                    │             │           │                                 │                                 │            │                         │                │                                  │
# │ sizeof(ifr.ifr_name) - 1)', 'typeFullName':  │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '<empty>', 'columnNumber': 2, 'order': 14,   │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strncpy', '_label':       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 82, 'id': 187188}              │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strncpy', 'signature': '', 'code': │ strncpy(p.name, "tun6to4", sizeof(p.name) -  │ <global>    │ CALL      │ tunnel_destroy                  │ tunnel_destroy                  │        114 │ src/6to4.c              │ <global>       │ src/6to4.c:<global>              │
# │ 'strncpy(p.name, "tun6to4", sizeof(p.name) - │ 1)                                           │             │           │                                 │                                 │            │                         │                │                                  │
# │ 1)', 'typeFullName': '<empty>',              │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'columnNumber': 2, 'order': 12,              │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strncpy', '_label':       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 114, 'id': 187299}             │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strncpy', 'signature': '', 'code': │ strncpy(ifr.ifr_name, "tun6to4",             │ <global>    │ CALL      │ tunnel_destroy                  │ tunnel_destroy                  │        116 │ src/6to4.c              │ <global>       │ src/6to4.c:<global>              │
# │ 'strncpy(ifr.ifr_name, "tun6to4",            │ sizeof(ifr.ifr_name) - 1)                    │             │           │                                 │                                 │            │                         │                │                                  │
# │ sizeof(ifr.ifr_name) - 1)', 'typeFullName':  │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '<empty>', 'columnNumber': 2, 'order': 13,   │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strncpy', '_label':       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 116, 'id': 187310}             │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strncpy', 'signature': '', 'code': │ strncpy(question, (char *) ptr, qlen)        │ <global>    │ CALL      │ parse_response                  │ parse_response                  │       1006 │ src/dnsproxy.c          │ <global>       │ src/dnsproxy.c:<global>          │
# │ 'strncpy(question, (char *) ptr, qlen)',     │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'typeFullName': '<empty>', 'columnNumber':   │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 2, 'order': 25, 'methodFullName': 'strncpy', │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '_label': 'CALL', 'argumentIndex': -1,       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 1006, 'id': 199231}            │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strncpy', 'signature': '', 'code': │ strncpy(dns_name, entry->key, NS_MAXDNAME)   │ <global>    │ CALL      │ cache_refresh_entry             │ cache_refresh_entry             │       1332 │ src/dnsproxy.c          │ <global>       │ src/dnsproxy.c:<global>          │
# │ 'strncpy(dns_name, entry->key,               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ NS_MAXDNAME)', 'typeFullName': '<empty>',    │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'columnNumber': 3, 'order': 4,               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strncpy', '_label':       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 1332, 'id': 199894}            │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strncpy', 'signature': '', 'code': │ strncpy(uptr, name, uncomp_len - (uptr -     │ <global>    │ CALL      │ uncompress                      │ uncompress                      │       1791 │ src/dnsproxy.c          │ <global>       │ src/dnsproxy.c:<global>          │
# │ 'strncpy(uptr, name, uncomp_len - (uptr -    │ uncompressed))                               │             │           │                                 │                                 │            │                         │                │                                  │
# │ uncompressed))', 'typeFullName': '<empty>',  │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'columnNumber': 3, 'order': 10,              │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strncpy', '_label':       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ...
# │ 'lineNumber': 1224, 'id': 245702}            │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strcpy', 'signature': '', 'code':  │ strcpy(ifname, RTA_DATA(rta))                │ <global>    │ CALL      │ getlink_callback                │ getlink_callback                │         84 │ tools/netlink-test.c    │ <global>       │ tools/netlink-test.c:<global>    │
# │ 'strcpy(ifname, RTA_DATA(rta))',             │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'typeFullName': '<empty>', 'columnNumber':   │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 5, 'order': 1, 'methodFullName': 'strcpy',   │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '_label': 'CALL', 'argumentIndex': -1,       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 84, 'id': 64678}               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strcpy', 'signature': '', 'code':  │ strcpy(username, user)                       │ <global>    │ CALL      │ ppp_get_secret                  │ ppp_get_secret                  │        132 │ scripts/libppp-plugin.c │ <global>       │ scripts/libppp-plugin.c:<global> │
# │ 'strcpy(username, user)', 'typeFullName':    │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '<empty>', 'columnNumber': 3, 'order': 1,    │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strcpy', '_label':        │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 132, 'id': 211738}             │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strcpy', 'signature': '', 'code':  │ strcpy(password, pass)                       │ <global>    │ CALL      │ ppp_get_secret                  │ ppp_get_secret                  │        134 │ scripts/libppp-plugin.c │ <global>       │ scripts/libppp-plugin.c:<global> │
# │ 'strcpy(password, pass)', 'typeFullName':    │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '<empty>', 'columnNumber': 2, 'order': 19,   │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'methodFullName': 'strcpy', '_label':        │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'CALL', 'argumentIndex': -1,                 │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 134, 'id': 211741}             │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strcpy', 'signature': '', 'code':  │ strcpy(buf, "255.255.255.255")               │ <global>    │ CALL      │ ppp_up                          │ ppp_up                          │        178 │ scripts/libppp-plugin.c │ <global>       │ scripts/libppp-plugin.c:<global> │
# │ 'strcpy(buf, "255.255.255.255")',            │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'typeFullName': '<empty>', 'columnNumber':   │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 2, 'order': 21, 'methodFullName': 'strcpy',  │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '_label': 'CALL', 'argumentIndex': -1,       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 178, 'id': 211828}             │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strcpy', 'signature': '', 'code':  │ strcpy(ifr.ifr_name, "lo")                   │ <global>    │ CALL      │ setup_loopback                  │ setup_loopback                  │        142 │ plugins/loopback.c      │ <global>       │ plugins/loopback.c:<global>      │
# │ 'strcpy(ifr.ifr_name, "lo")',                │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'typeFullName': '<empty>', 'columnNumber':   │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 2, 'order': 8, 'methodFullName': 'strcpy',   │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '_label': 'CALL', 'argumentIndex': -1,       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 142, 'id': 221936}             │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# ├──────────────────────────────────────────────┼──────────────────────────────────────────────┼─────────────┼───────────┼─────────────────────────────────┼─────────────────────────────────┼────────────┼─────────────────────────┼────────────────┼──────────────────────────────────┤
# │ {'name': 'strcpy', 'signature': '', 'code':  │ strcpy(ifname, ifa->ifa_name)                │ <global>    │ CALL      │ get_peer_iface                  │ get_peer_iface                  │       3318 │ src/inet.c              │ <global>       │ src/inet.c:<global>              │
# │ 'strcpy(ifname, ifa->ifa_name)',             │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'typeFullName': '<empty>', 'columnNumber':   │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 4, 'order': 1, 'methodFullName': 'strcpy',   │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ '_label': 'CALL', 'argumentIndex': -1,       │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dynamicTypeHintFullName': [],               │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'dispatchType': 'STATIC_DISPATCH',           │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# │ 'lineNumber': 3318, 'id': 251934}            │                                              │             │           │                                 │                                 │            │                         │                │                                  │
# └──────────────────────────────────────────────┴──────────────────────────────────────────────┴─────────────┴───────────┴─────────────────────────────────┴─────────────────────────────────┴────────────┴─────────────────────────┴────────────────┴──────────────────────────────────┘

# %% [markdown]
# ## Detect malloc memcpy overflow
#
# Dangerous copy-operation into heap-allocated buffer.

# %%
async def malloc_overflow():
    connection = await client.get(joern_host, joern_username, joern_password)
    res = await client.p(connection, """
        ({val src =
            cpg.method(".*malloc$").callIn.where(_.argument(1).arithmetic).l

            cpg.method("(?i)memcpy").callIn.l.filter { memcpyCall =>
            memcpyCall
                .argument(1)
                .reachableBy(src)
                .where(_.inAssignment.target.codeExact(memcpyCall.argument(1).code))
                .whereNot(_.argument(1).codeExact(memcpyCall.argument(3).code))
                .hasNext
        }}).location.toJsonPretty
    """, title="Malloc memcpy overflow problems")
asyncio.run(malloc_overflow())
# Out:
#                                                                                                                             Malloc memcpy overflow problems
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ node                                             ┃ symbol                                           ┃ packageName ┃ nodeLabel ┃ methodShortName            ┃ methodFullName             ┃ lineNumber ┃ filename                 ┃ classShortName ┃ className                         ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ {'name': 'memcpy', 'signature': '', 'code':      │ memcpy(interface->network_info.ssid, ssid->ssid, │ <global>    │ CALL      │ store_network_information  │ store_network_information  │        439 │ gsupplicant/supplicant.c │ <global>       │ gsupplicant/supplicant.c:<global> │
# │ 'memcpy(interface->network_info.ssid,            │                         ssid->ssid_len)          │             │           │                            │                            │            │                          │                │                                   │
# │ ssid->ssid,\n\t\t\tssid->ssid_len)',             │                                                  │             │           │                            │                            │            │                          │                │                                   │
# │ 'typeFullName': '<empty>', 'columnNumber': 3,    │                                                  │             │           │                            │                            │            │                          │                │                                   │
# │ 'order': 1, 'methodFullName': 'memcpy',          │                                                  │             │           │                            │                            │            │                          │                │                                   │
# │ '_label': 'CALL', 'argumentIndex': -1,           │                                                  │             │           │                            │                            │            │                          │                │                                   │
# │ 'dynamicTypeHintFullName': [], 'dispatchType':   │                                                  │             │           │                            │                            │            │                          │                │                                   │
# │ 'STATIC_DISPATCH', 'lineNumber': 439, 'id':      │                                                  │             │           │                            │                            │            │                          │                │                                   │
# │ 25821}                                           │                                                  │             │           │                            │                            │            │                          │                │                                   │
# ├──────────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────┼───────────┼────────────────────────────┼────────────────────────────┼────────────┼──────────────────────────┼────────────────┼───────────────────────────────────┤
# │ {'name': 'memcpy', 'signature': '', 'code':      │ memcpy(dest, option, len)                        │ <global>    │ CALL      │ malloc_option_value_string │ malloc_option_value_string │       1877 │ gdhcp/client.c           │ <global>       │ gdhcp/client.c:<global>           │
# │ 'memcpy(dest, option, len)', 'typeFullName':     │                                                  │             │           │                            │                            │            │                          │                │                                   │
# │ '<empty>', 'columnNumber': 4, 'order': 13,       │                                                  │             │           │                            │                            │            │                          │                │                                   │
# │ 'methodFullName': 'memcpy', '_label': 'CALL',    │                                                  │             │           │                            │                            │            │                          │                │                                   │
# │ 'argumentIndex': -1, 'dynamicTypeHintFullName':  │                                                  │             │           │                            │                            │            │                          │                │                                   │
# │ [], 'dispatchType': 'STATIC_DISPATCH',           │                                                  │             │           │                            │                            │            │                          │                │                                   │
# │ 'lineNumber': 1877, 'id': 84179}                 │                                                  │             │           │                            │                            │            │                          │                │                                   │
# └──────────────────────────────────────────────────┴──────────────────────────────────────────────────┴─────────────┴───────────┴────────────────────────────┴────────────────────────────┴────────────┴──────────────────────────┴────────────────┴───────────────────────────────────┘

# %% [markdown]
# ## Free follows value reuse
#
# A value that is free'd is reused without reassignment. A value is used after being free'd in a path that leads to it without reassignment. Modeled after CVE-2019-18903.

# %%
async def free_reuse():
    connection = await client.get(joern_host, joern_username, joern_password)
    res = await client.p(connection, """
        ({cpg.method
            .name("(.*_)?free")
            .filter(_.parameter.size == 1)
            .callIn
            .where(_.argument(1).isIdentifier)
            .flatMap(f => {
                val freedIdentifierCode = f.argument(1).code
                val postDom             = f.postDominatedBy.toSetImmutable

                val assignedPostDom = postDom.isIdentifier
                .where(_.inAssignment)
                .codeExact(freedIdentifierCode)
                .flatMap(id => id ++ id.postDominatedBy)

                postDom
                .removedAll(assignedPostDom)
                .isIdentifier
                .codeExact(freedIdentifierCode)
            })}).location.toJsonPretty
    """, title="Free follows reuse problems")
asyncio.run(free_reuse())
# Out:
#                                                                                                                               Free follows reuse problems
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ node                                                                                                             ┃ symbol    ┃ packageName ┃ nodeLabel  ┃ methodShortName     ┃ methodFullName      ┃ lineNumber ┃ filename           ┃ classShortName ┃ className                   ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ {'dynamicTypeHintFullName': [], 'name': 'dhcp', 'code': 'dhcp', 'typeFullName': 'connman_dhcpv6',                │ dhcp      │ <global>    │ IDENTIFIER │ dhcpv6_release      │ dhcpv6_release      │       1555 │ src/dhcpv6.c       │ <global>       │ src/dhcpv6.c:<global>       │
# │ 'columnNumber': 7, 'order': 1, '_label': 'IDENTIFIER', 'argumentIndex': 1, 'lineNumber': 1555, 'id': 260469}     │           │             │            │                     │                     │            │                    │                │                             │
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────┼─────────────┼────────────┼─────────────────────┼─────────────────────┼────────────┼────────────────────┼────────────────┼─────────────────────────────┤
# │ {'dynamicTypeHintFullName': [], 'name': 'info', 'code': 'info', 'typeFullName': 'wifi_tethering_info',           │ info      │ <global>    │ IDENTIFIER │ sta_remove_callback │ sta_remove_callback │       3365 │ plugins/wifi.c     │ <global>       │ plugins/wifi.c:<global>     │
# │ 'columnNumber': 7, 'order': 1, '_label': 'IDENTIFIER', 'argumentIndex': 1, 'lineNumber': 3365, 'id': 49571}      │           │             │            │                     │                     │            │                    │                │                             │
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────┼─────────────┼────────────┼─────────────────────┼─────────────────────┼────────────┼────────────────────┼────────────────┼─────────────────────────────┤
# │ {'dynamicTypeHintFullName': [], 'name': 'conf_file', 'code': 'conf_file', 'typeFullName': 'char',                │ conf_file │ <global>    │ IDENTIFIER │ l2tp_died           │ l2tp_died           │        480 │ vpn/plugins/l2tp.c │ <global>       │ vpn/plugins/l2tp.c:<global> │
# │ 'columnNumber': 9, 'order': 1, '_label': 'IDENTIFIER', 'argumentIndex': 1, 'lineNumber': 480, 'id': 74199}       │           │             │            │                     │                     │            │                    │                │                             │
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────┼─────────────┼────────────┼─────────────────────┼─────────────────────┼────────────┼────────────────────┼────────────────┼─────────────────────────────┤
# │ {'dynamicTypeHintFullName': [], 'name': 'conf_file', 'code': 'conf_file', 'typeFullName': 'char',                │ conf_file │ <global>    │ IDENTIFIER │ l2tp_died           │ l2tp_died           │        481 │ vpn/plugins/l2tp.c │ <global>       │ vpn/plugins/l2tp.c:<global> │
# │ 'columnNumber': 9, 'order': 1, '_label': 'IDENTIFIER', 'argumentIndex': 1, 'lineNumber': 481, 'id': 74201}       │           │             │            │                     │                     │            │                    │                │                             │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────────┴─────────────┴────────────┴─────────────────────┴─────────────────────┴────────────┴────────────────────┴────────────────┴─────────────────────────────┘

# %% [markdown]
# ## Just show me the CVE!!
#
# Source: Parameter to the method `tcp_server_event`
# Sink: Argument from the call `strncpy`

# %%
async def find_reachable_flows():
    connection = await client.get(joern_host, joern_username, joern_password)
    await client.flows(connection, 'def source=cpg.method(".*tcp_server_event.*").parameter', 'def sink=cpg.call(".*strncpy.*").argument')
asyncio.run(find_reachable_flows())
# Out:
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# | nodeType           | tracked                                                                                                                         | lineNumber| method            | file           |
# |=======================================================================================================================================================================================================|
# | MethodParameterIn  | tcp_server_event(GIOChannel *channel, GIOCondition condition, gpointer user_data)                                               | 2253      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | g_io_channel_unix_get_fd(channel)                                                                                               | 2259      | tcp_server_event  | src/dnsproxy.c |
# | Call               | g_io_channel_unix_get_fd(channel)                                                                                               | 2259      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | sk = g_io_channel_unix_get_fd(channel)                                                                                          | 2259      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | sk == 0                                                                                                                         | 2260      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | recv(sk, reply_len_buf, 2, MSG_PEEK)                                                                                            | 2389      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | recv(sk, reply_len_buf, 2, MSG_PEEK)                                                                                            | 2389      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply_len_buf[0] << 8                                                                                                           | 2402      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply_len_buf[0] << 8                                                                                                           | 2402      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply_len_buf[1] | reply_len_buf[0] << 8                                                                                        | 2402      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply_len_buf[1] | reply_len_buf[0] << 8                                                                                        | 2402      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | reply_len = reply_len_buf[1] | reply_len_buf[0] << 8                                                                            | 2402      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | reply_len += 2                                                                                                                  | 2403      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | reply->len = reply_len                                                                                                          | 2411      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply->len = reply_len                                                                                                          | 2411      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply->received < reply->len                                                                                                    | 2417      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply->len - reply->received                                                                                                    | 2419      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply->len - reply->received                                                                                                    | 2419      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply->len - reply->received                                                                                                    | 2419      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply->buf + reply->received                                                                                                    | 2418      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | recv(sk, reply->buf + reply->received, reply->len - reply->received, 0)                                                         | 2418      | tcp_server_event  | src/dnsproxy.c |
# | Call               | recv(sk, reply->buf + reply->received, reply->len - reply->received, 0)                                                         | 2418      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | bytes_recv = recv(sk, reply->buf + reply->received, reply->len - reply->received, 0)                                            | 2418      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | !bytes_recv                                                                                                                     | 2420      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | bytes_recv < 0                                                                                                                  | 2423      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | reply->received += bytes_recv                                                                                                   | 2431      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply->received += bytes_recv                                                                                                   | 2431      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply->received < reply->len                                                                                                    | 2417      | tcp_server_event  | src/dnsproxy.c |
# | Call               | forward_dns_reply(reply->buf, reply->received, IPPROTO_TCP, server)                                                             | 2434      | tcp_server_event  | src/dnsproxy.c |
# | MethodParameterIn  | forward_dns_reply(unsigned char *reply, int reply_len, int protocol, struct server_data *data)                                  | 1935      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | reply_len - header_len                                                                                                          | 1995      | forward_dns_reply | src/dnsproxy.c |
# | Call               | reply_len - header_len                                                                                                          | 1995      | forward_dns_reply | src/dnsproxy.c |
# | Call               | ptr + 1 + host_len                                                                                                              | 1994      | forward_dns_reply | src/dnsproxy.c |
# | Call               | strnlen(ptr + 1 + host_len, reply_len - header_len)                                                                             | 1994      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | domain_len = strnlen(ptr + 1 + host_len, reply_len - header_len)                                                                | 1994      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | domain_len > 0                                                                                                                  | 2028      | forward_dns_reply | src/dnsproxy.c |
# | Call               | len + domain_len + 1                                                                                                            | 2046      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | ptr += len + domain_len + 1                                                                                                     | 2046      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, NS_QFIXEDSZ)                                                                                                  | 2047      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, NS_QFIXEDSZ)                                                                                                  | 2047      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | uptr += NS_QFIXEDSZ                                                                                                             | 2053      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | answers = uptr                                                                                                                  | 2054      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | answers = uptr                                                                                                                  | 2054      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | answers - uncompressed                                                                                                          | 2055      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | answers - uncompressed                                                                                                          | 2055      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | uncompress(ntohs(hdr->ancount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                             | 2067      | forward_dns_reply | src/dnsproxy.c |
# | MethodParameterIn  | uncompress(int16_t field_count, char *start, char *end, char *ptr, char *uncompressed, int uncomp_len, char **uncompressed_ptr) | 1766      | uncompress        | src/dnsproxy.c |
# | Identifier         | uptr - uncompressed                                                                                                             | 1791      | uncompress        | src/dnsproxy.c |
# | Identifier         | uptr - uncompressed                                                                                                             | 1791      | uncompress        | src/dnsproxy.c |
# | Identifier         | strncpy(uptr, name, uncomp_len - (uptr - uncompressed))                                                                         | 1791      | uncompress        | src/dnsproxy.c |
# | Identifier         | uptr += ulen                                                                                                                    | 1796      | uncompress        | src/dnsproxy.c |
# | Identifier         | uptr++                                                                                                                          | 1797      | uncompress        | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, NS_RRFIXEDSZ)                                                                                                 | 1805      | uncompress        | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, NS_RRFIXEDSZ)                                                                                                 | 1805      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr += NS_RRFIXEDSZ                                                                                                             | 1813      | uncompress        | src/dnsproxy.c |
# | Call               | ptr + dlen                                                                                                                      | 1836      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr + dlen > end                                                                                                                | 1836      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr < end                                                                                                                       | 1773      | uncompress        | src/dnsproxy.c |
# | MethodParameterOut | RET                                                                                                                             | 1765      | uncompress        | src/dnsproxy.c |
# | Identifier         | uncompress(ntohs(hdr->ancount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                             | 2066      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | uncompress(ntohs(hdr->nscount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                             | 2073      | forward_dns_reply | src/dnsproxy.c |
# | MethodParameterIn  | uncompress(int16_t field_count, char *start, char *end, char *ptr, char *uncompressed, int uncomp_len, char **uncompressed_ptr) | 1765      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr < end                                                                                                                       | 1773      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr < end                                                                                                                       | 1773      | uncompress        | src/dnsproxy.c |
# | Identifier         | return ptr;                                                                                                                     | 1890      | uncompress        | src/dnsproxy.c |
# | Return             | return ptr;                                                                                                                     | 1890      | uncompress        | src/dnsproxy.c |
# | MethodReturn       | RET                                                                                                                             | 1765      | uncompress        | src/dnsproxy.c |
# | Call               | uncompress(ntohs(hdr->nscount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                             | 2072      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | ptr = uncompress(ntohs(hdr->nscount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                       | 2072      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | !ptr                                                                                                                            | 2076      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | uncompress(ntohs(hdr->arcount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                             | 2081      | forward_dns_reply | src/dnsproxy.c |
# | MethodParameterIn  | uncompress(int16_t field_count, char *start, char *end, char *ptr, char *uncompressed, int uncomp_len, char **uncompressed_ptr) | 1766      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr < end                                                                                                                       | 1773      | uncompress        | src/dnsproxy.c |
# | Identifier         | convert_label(start, end, ptr, name, NS_MAXLABEL, &pos, &comp_pos)                                                              | 1781      | uncompress        | src/dnsproxy.c |
# | MethodParameterIn  | convert_label(char *start, char *end, char *ptr, char *uptr, int remaining_len, int *used_comp, int *used_uncomp)               | 1733      | convert_label     | src/dnsproxy.c |
# | Identifier         | (u_char *)ptr                                                                                                                   | 1739      | convert_label     | src/dnsproxy.c |
# | MethodParameterOut | RET                                                                                                                             | 1733      | convert_label     | src/dnsproxy.c |
# | Identifier         | convert_label(start, end, ptr, name, NS_MAXLABEL, &pos, &comp_pos)                                                              | 1781      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr += pos                                                                                                                      | 1799      | uncompress        | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, NS_RRFIXEDSZ)                                                                                                 | 1805      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr += NS_RRFIXEDSZ                                                                                                             | 1813      | uncompress        | src/dnsproxy.c |
# | Call               | ptr + dlen                                                                                                                      | 1836      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr + dlen > end                                                                                                                | 1836      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr < end                                                                                                                       | 1773      | uncompress        | src/dnsproxy.c |
# | Identifier         | convert_label(start, end, ptr, name, NS_MAXLABEL, &pos, &comp_pos)                                                              | 1781      | uncompress        | src/dnsproxy.c |
# | MethodParameterIn  | convert_label(char *start, char *end, char *ptr, char *uptr, int remaining_len, int *used_comp, int *used_uncomp)               | 1733      | convert_label     | src/dnsproxy.c |
# | Call               | (u_char *)end                                                                                                                   | 1739      | convert_label     | src/dnsproxy.c |
# | Identifier         | dn_expand((u_char *)start, (u_char *)end, (u_char *)ptr, name, NS_MAXLABEL)                                                     | 1740      | convert_label     | src/dnsproxy.c |
# | Call               | (u_char *)ptr                                                                                                                   | 1739      | convert_label     | src/dnsproxy.c |
# | Call               | dn_expand((u_char *)start, (u_char *)end, (u_char *)ptr, name, NS_MAXLABEL)                                                     | 1739      | convert_label     | src/dnsproxy.c |
# | Identifier         | pos = dn_expand((u_char *)start, (u_char *)end, (u_char *)ptr, name, NS_MAXLABEL)                                               | 1739      | convert_label     | src/dnsproxy.c |
# | Identifier         | pos < 0                                                                                                                         | 1741      | convert_label     | src/dnsproxy.c |
# | Identifier         | *used_comp = pos                                                                                                                | 1756      | convert_label     | src/dnsproxy.c |
# | Call               | *used_comp = pos                                                                                                                | 1756      | convert_label     | src/dnsproxy.c |
# | MethodParameterOut | RET                                                                                                                             | 1734      | convert_label     | src/dnsproxy.c |
# | Call               | convert_label(start, end, ptr, name, NS_MAXLABEL, &pos, &comp_pos)                                                              | 1782      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr += pos                                                                                                                      | 1857      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr += pos                                                                                                                      | 1857      | uncompress        | src/dnsproxy.c |
# | Identifier         | convert_label(start, end, ptr, uptr, uncomp_len - (uptr - uncompressed), &pos, &comp_pos)                                       | 1861      | uncompress        | src/dnsproxy.c |
# | MethodParameterIn  | convert_label(char *start, char *end, char *ptr, char *uptr, int remaining_len, int *used_comp, int *used_uncomp)               | 1733      | convert_label     | src/dnsproxy.c |
# | Identifier         | (u_char *)ptr                                                                                                                   | 1739      | convert_label     | src/dnsproxy.c |
# | MethodParameterOut | RET                                                                                                                             | 1733      | convert_label     | src/dnsproxy.c |
# | Identifier         | convert_label(start, end, ptr, uptr, uncomp_len - (uptr - uncompressed), &pos, &comp_pos)                                       | 1861      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr += pos                                                                                                                      | 1867      | uncompress        | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, 20)                                                                                                           | 1875      | uncompress        | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, 20)                                                                                                           | 1875      | uncompress        | src/dnsproxy.c |
# | Identifier         | uptr += 20                                                                                                                      | 1876      | uncompress        | src/dnsproxy.c |
# | Identifier         | uptr - uncompressed                                                                                                             | 1791      | uncompress        | src/dnsproxy.c |
# | Identifier         | strncpy(uptr, name, uncomp_len - (uptr - uncompressed))                                                                         | 1791      | uncompress        | src/dnsproxy.c |
#
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# | nodeType           | tracked                                                                                                                         | lineNumber| method            | file           |
# |=======================================================================================================================================================================================================|
# | MethodParameterIn  | tcp_server_event(GIOChannel *channel, GIOCondition condition, gpointer user_data)                                               | 2253      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | g_io_channel_unix_get_fd(channel)                                                                                               | 2259      | tcp_server_event  | src/dnsproxy.c |
# | Call               | g_io_channel_unix_get_fd(channel)                                                                                               | 2259      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | sk = g_io_channel_unix_get_fd(channel)                                                                                          | 2259      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | sk == 0                                                                                                                         | 2260      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | recv(sk, reply_len_buf, 2, MSG_PEEK)                                                                                            | 2389      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | recv(sk, reply_len_buf, 2, MSG_PEEK)                                                                                            | 2389      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply_len_buf[0] << 8                                                                                                           | 2402      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply_len_buf[0] << 8                                                                                                           | 2402      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply_len_buf[1] | reply_len_buf[0] << 8                                                                                        | 2402      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply_len_buf[1] | reply_len_buf[0] << 8                                                                                        | 2402      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | reply_len = reply_len_buf[1] | reply_len_buf[0] << 8                                                                            | 2402      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | reply_len += 2                                                                                                                  | 2403      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | reply->len = reply_len                                                                                                          | 2411      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply->len = reply_len                                                                                                          | 2411      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply->received < reply->len                                                                                                    | 2417      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply->len - reply->received                                                                                                    | 2419      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply->len - reply->received                                                                                                    | 2419      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply->len - reply->received                                                                                                    | 2419      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply->buf + reply->received                                                                                                    | 2418      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | recv(sk, reply->buf + reply->received, reply->len - reply->received, 0)                                                         | 2418      | tcp_server_event  | src/dnsproxy.c |
# | Call               | recv(sk, reply->buf + reply->received, reply->len - reply->received, 0)                                                         | 2418      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | bytes_recv = recv(sk, reply->buf + reply->received, reply->len - reply->received, 0)                                            | 2418      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | !bytes_recv                                                                                                                     | 2420      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | bytes_recv < 0                                                                                                                  | 2423      | tcp_server_event  | src/dnsproxy.c |
# | Identifier         | reply->received += bytes_recv                                                                                                   | 2431      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply->received += bytes_recv                                                                                                   | 2431      | tcp_server_event  | src/dnsproxy.c |
# | Call               | reply->received < reply->len                                                                                                    | 2417      | tcp_server_event  | src/dnsproxy.c |
# | Call               | forward_dns_reply(reply->buf, reply->received, IPPROTO_TCP, server)                                                             | 2434      | tcp_server_event  | src/dnsproxy.c |
# | MethodParameterIn  | forward_dns_reply(unsigned char *reply, int reply_len, int protocol, struct server_data *data)                                  | 1935      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | reply_len - header_len                                                                                                          | 1995      | forward_dns_reply | src/dnsproxy.c |
# | Call               | reply_len - header_len                                                                                                          | 1995      | forward_dns_reply | src/dnsproxy.c |
# | Call               | ptr + 1 + host_len                                                                                                              | 1994      | forward_dns_reply | src/dnsproxy.c |
# | Call               | strnlen(ptr + 1 + host_len, reply_len - header_len)                                                                             | 1994      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | domain_len = strnlen(ptr + 1 + host_len, reply_len - header_len)                                                                | 1994      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | domain_len > 0                                                                                                                  | 2028      | forward_dns_reply | src/dnsproxy.c |
# | Call               | len + domain_len + 1                                                                                                            | 2046      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | ptr += len + domain_len + 1                                                                                                     | 2046      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, NS_QFIXEDSZ)                                                                                                  | 2047      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, NS_QFIXEDSZ)                                                                                                  | 2047      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | uptr += NS_QFIXEDSZ                                                                                                             | 2053      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | answers = uptr                                                                                                                  | 2054      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | answers = uptr                                                                                                                  | 2054      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | answers - uncompressed                                                                                                          | 2055      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | answers - uncompressed                                                                                                          | 2055      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | uncompress(ntohs(hdr->ancount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                             | 2067      | forward_dns_reply | src/dnsproxy.c |
# | MethodParameterIn  | uncompress(int16_t field_count, char *start, char *end, char *ptr, char *uncompressed, int uncomp_len, char **uncompressed_ptr) | 1766      | uncompress        | src/dnsproxy.c |
# | Identifier         | uptr - uncompressed                                                                                                             | 1791      | uncompress        | src/dnsproxy.c |
# | Identifier         | uptr - uncompressed                                                                                                             | 1791      | uncompress        | src/dnsproxy.c |
# | Identifier         | strncpy(uptr, name, uncomp_len - (uptr - uncompressed))                                                                         | 1791      | uncompress        | src/dnsproxy.c |
# | Identifier         | uptr += ulen                                                                                                                    | 1796      | uncompress        | src/dnsproxy.c |
# | Identifier         | uptr++                                                                                                                          | 1797      | uncompress        | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, NS_RRFIXEDSZ)                                                                                                 | 1805      | uncompress        | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, NS_RRFIXEDSZ)                                                                                                 | 1805      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr += NS_RRFIXEDSZ                                                                                                             | 1813      | uncompress        | src/dnsproxy.c |
# | Call               | ptr + dlen                                                                                                                      | 1836      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr + dlen > end                                                                                                                | 1836      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr < end                                                                                                                       | 1773      | uncompress        | src/dnsproxy.c |
# | MethodParameterOut | RET                                                                                                                             | 1765      | uncompress        | src/dnsproxy.c |
# | Identifier         | uncompress(ntohs(hdr->ancount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                             | 2066      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | uncompress(ntohs(hdr->nscount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                             | 2073      | forward_dns_reply | src/dnsproxy.c |
# | MethodParameterIn  | uncompress(int16_t field_count, char *start, char *end, char *ptr, char *uncompressed, int uncomp_len, char **uncompressed_ptr) | 1765      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr < end                                                                                                                       | 1773      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr < end                                                                                                                       | 1773      | uncompress        | src/dnsproxy.c |
# | Identifier         | return ptr;                                                                                                                     | 1890      | uncompress        | src/dnsproxy.c |
# | Return             | return ptr;                                                                                                                     | 1890      | uncompress        | src/dnsproxy.c |
# | MethodReturn       | RET                                                                                                                             | 1765      | uncompress        | src/dnsproxy.c |
# | Call               | uncompress(ntohs(hdr->nscount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                             | 2072      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | ptr = uncompress(ntohs(hdr->nscount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                       | 2072      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | !ptr                                                                                                                            | 2076      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | uncompress(ntohs(hdr->arcount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                             | 2081      | forward_dns_reply | src/dnsproxy.c |
# | MethodParameterIn  | uncompress(int16_t field_count, char *start, char *end, char *ptr, char *uncompressed, int uncomp_len, char **uncompressed_ptr) | 1766      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr < end                                                                                                                       | 1773      | uncompress        | src/dnsproxy.c |
# | Identifier         | convert_label(start, end, ptr, name, NS_MAXLABEL, &pos, &comp_pos)                                                              | 1781      | uncompress        | src/dnsproxy.c |
# | MethodParameterIn  | convert_label(char *start, char *end, char *ptr, char *uptr, int remaining_len, int *used_comp, int *used_uncomp)               | 1733      | convert_label     | src/dnsproxy.c |
# | Identifier         | (u_char *)ptr                                                                                                                   | 1739      | convert_label     | src/dnsproxy.c |
# | MethodParameterOut | RET                                                                                                                             | 1733      | convert_label     | src/dnsproxy.c |
# | Identifier         | convert_label(start, end, ptr, name, NS_MAXLABEL, &pos, &comp_pos)                                                              | 1781      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr += pos                                                                                                                      | 1799      | uncompress        | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, NS_RRFIXEDSZ)                                                                                                 | 1805      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr += NS_RRFIXEDSZ                                                                                                             | 1813      | uncompress        | src/dnsproxy.c |
# | Call               | ptr + dlen                                                                                                                      | 1836      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr + dlen > end                                                                                                                | 1836      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr < end                                                                                                                       | 1773      | uncompress        | src/dnsproxy.c |
# | Identifier         | convert_label(start, end, ptr, name, NS_MAXLABEL, &pos, &comp_pos)                                                              | 1781      | uncompress        | src/dnsproxy.c |
# | MethodParameterIn  | convert_label(char *start, char *end, char *ptr, char *uptr, int remaining_len, int *used_comp, int *used_uncomp)               | 1733      | convert_label     | src/dnsproxy.c |
# | Call               | (u_char *)end                                                                                                                   | 1739      | convert_label     | src/dnsproxy.c |
# | Identifier         | dn_expand((u_char *)start, (u_char *)end, (u_char *)ptr, name, NS_MAXLABEL)                                                     | 1740      | convert_label     | src/dnsproxy.c |
# | Call               | (u_char *)ptr                                                                                                                   | 1739      | convert_label     | src/dnsproxy.c |
# | Call               | dn_expand((u_char *)start, (u_char *)end, (u_char *)ptr, name, NS_MAXLABEL)                                                     | 1739      | convert_label     | src/dnsproxy.c |
# | Identifier         | pos = dn_expand((u_char *)start, (u_char *)end, (u_char *)ptr, name, NS_MAXLABEL)                                               | 1739      | convert_label     | src/dnsproxy.c |
# | Identifier         | pos < 0                                                                                                                         | 1741      | convert_label     | src/dnsproxy.c |
# | Identifier         | *used_comp = pos                                                                                                                | 1756      | convert_label     | src/dnsproxy.c |
# | Call               | *used_comp = pos                                                                                                                | 1756      | convert_label     | src/dnsproxy.c |
# | MethodParameterOut | RET                                                                                                                             | 1734      | convert_label     | src/dnsproxy.c |
# | Call               | convert_label(start, end, ptr, name, NS_MAXLABEL, &pos, &comp_pos)                                                              | 1782      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr += pos                                                                                                                      | 1857      | uncompress        | src/dnsproxy.c |
# | Identifier         | ptr += pos                                                                                                                      | 1857      | uncompress        | src/dnsproxy.c |
# | Identifier         | convert_label(start, end, ptr, uptr, uncomp_len - (uptr - uncompressed), &pos, &comp_pos)                                       | 1861      | uncompress        | src/dnsproxy.c |
# | MethodParameterIn  | convert_label(char *start, char *end, char *ptr, char *uptr, int remaining_len, int *used_comp, int *used_uncomp)               | 1733      | convert_label     | src/dnsproxy.c |
# | Call               | (u_char *)ptr                                                                                                                   | 1739      | convert_label     | src/dnsproxy.c |
# | Identifier         | dn_expand((u_char *)start, (u_char *)end, (u_char *)ptr, name, NS_MAXLABEL)                                                     | 1740      | convert_label     | src/dnsproxy.c |
# | Identifier         | dn_comp(name, (u_char *)uptr, remaining_len, NULL, NULL)                                                                        | 1750      | convert_label     | src/dnsproxy.c |
# | Identifier         | dn_comp(name, (u_char *)uptr, remaining_len, NULL, NULL)                                                                        | 1750      | convert_label     | src/dnsproxy.c |
# | Call               | (u_char *)uptr                                                                                                                  | 1750      | convert_label     | src/dnsproxy.c |
# | Call               | dn_comp(name, (u_char *)uptr, remaining_len, NULL, NULL)                                                                        | 1750      | convert_label     | src/dnsproxy.c |
# | Identifier         | comp_pos = dn_comp(name, (u_char *)uptr, remaining_len, NULL, NULL)                                                             | 1750      | convert_label     | src/dnsproxy.c |
# | Identifier         | comp_pos < 0                                                                                                                    | 1751      | convert_label     | src/dnsproxy.c |
# | Identifier         | *used_uncomp = comp_pos                                                                                                         | 1757      | convert_label     | src/dnsproxy.c |
# | Call               | *used_uncomp = comp_pos                                                                                                         | 1757      | convert_label     | src/dnsproxy.c |
# | MethodParameterOut | RET                                                                                                                             | 1734      | convert_label     | src/dnsproxy.c |
# | Call               | convert_label(start, end, ptr, uptr, uncomp_len - (uptr - uncompressed), &pos, &comp_pos)                                       | 1863      | uncompress        | src/dnsproxy.c |
# | Identifier         | comp_pos << 8                                                                                                                   | 1827      | uncompress        | src/dnsproxy.c |
# | Identifier         | comp_pos & 0xff                                                                                                                 | 1828      | uncompress        | src/dnsproxy.c |
# | Call               | comp_pos & 0xff                                                                                                                 | 1828      | uncompress        | src/dnsproxy.c |
# | Call               | uptr[-1] = comp_pos & 0xff                                                                                                      | 1828      | uncompress        | src/dnsproxy.c |
# | Call               | uptr[-2] << 8 | uptr[-1]                                                                                                        | 1834      | uncompress        | src/dnsproxy.c |
# | Call               | uptr[-2] << 8 | uptr[-1]                                                                                                        | 1834      | uncompress        | src/dnsproxy.c |
# | Identifier         | dlen = uptr[-2] << 8 | uptr[-1]                                                                                                 | 1834      | uncompress        | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, dlen)                                                                                                         | 1841      | uncompress        | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, dlen)                                                                                                         | 1841      | uncompress        | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, dlen)                                                                                                         | 1841      | uncompress        | src/dnsproxy.c |
# ...
# | Call               | reply_len - header_len                                                                                                           | 1995      | forward_dns_reply | src/dnsproxy.c |
# | Call               | ptr + 1 + host_len                                                                                                               | 1994      | forward_dns_reply | src/dnsproxy.c |
# | Call               | strnlen(ptr + 1 + host_len, reply_len - header_len)                                                                              | 1994      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | domain_len = strnlen(ptr + 1 + host_len, reply_len - header_len)                                                                 | 1994      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | domain_len > 0                                                                                                                   | 2028      | forward_dns_reply | src/dnsproxy.c |
# | Call               | len + domain_len + 1                                                                                                             | 2046      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | ptr += len + domain_len + 1                                                                                                      | 2046      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, NS_QFIXEDSZ)                                                                                                   | 2047      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, NS_QFIXEDSZ)                                                                                                   | 2047      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | uptr += NS_QFIXEDSZ                                                                                                              | 2053      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | answers = uptr                                                                                                                   | 2054      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | answers = uptr                                                                                                                   | 2054      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | answers - uncompressed                                                                                                           | 2055      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | answers - uncompressed                                                                                                           | 2055      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | uncompress(ntohs(hdr->ancount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                              | 2067      | forward_dns_reply | src/dnsproxy.c |
# | MethodParameterIn  | uncompress(int16_t field_count, char *start, char *end, char *ptr, char *uncompressed, int uncomp_len, char **uncompressed_ptr)  | 1766      | uncompress        | src/dnsproxy.c |
# | Identifier         | uptr - uncompressed                                                                                                              | 1791      | uncompress        | src/dnsproxy.c |
# | Identifier         | uptr - uncompressed                                                                                                              | 1791      | uncompress        | src/dnsproxy.c |
# | Identifier         | strncpy(uptr, name, uncomp_len - (uptr - uncompressed))                                                                          | 1791      | uncompress        | src/dnsproxy.c |
# | Identifier         | uptr += ulen                                                                                                                     | 1796      | uncompress        | src/dnsproxy.c |
# | Identifier         | uptr++                                                                                                                           | 1797      | uncompress        | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, NS_RRFIXEDSZ)                                                                                                  | 1805      | uncompress        | src/dnsproxy.c |
# | Call               | uptr[0] << 8                                                                                                                     | 1807      | uncompress        | src/dnsproxy.c |
# | Identifier         | uptr += comp_pos                                                                                                                 | 1868      | uncompress        | src/dnsproxy.c |
# | Identifier         | memcpy(uptr, ptr, 20)                                                                                                            | 1875      | uncompress        | src/dnsproxy.c |
# | Identifier         | uptr += 20                                                                                                                       | 1876      | uncompress        | src/dnsproxy.c |
# | Identifier         | *uncompressed_ptr = uptr                                                                                                         | 1887      | uncompress        | src/dnsproxy.c |
# | Call               | *uncompressed_ptr = uptr                                                                                                         | 1887      | uncompress        | src/dnsproxy.c |
# | MethodParameterOut | RET                                                                                                                              | 1767      | uncompress        | src/dnsproxy.c |
# | Call               | uncompress(ntohs(hdr->ancount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                              | 2068      | forward_dns_reply | src/dnsproxy.c |
# | Call               | uncompress(ntohs(hdr->nscount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                              | 2075      | forward_dns_reply | src/dnsproxy.c |
# | MethodParameterIn  | uncompress(int16_t field_count, char *start, char *end, char *ptr, char *uncompressed, int uncomp_len, char **uncompressed_ptr)  | 1767      | uncompress        | src/dnsproxy.c |
# | MethodParameterOut | RET                                                                                                                              | 1767      | uncompress        | src/dnsproxy.c |
# | Call               | uncompress(ntohs(hdr->nscount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                              | 2075      | forward_dns_reply | src/dnsproxy.c |
# | Call               | uncompress(ntohs(hdr->arcount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                              | 2082      | forward_dns_reply | src/dnsproxy.c |
# | MethodParameterIn  | uncompress(int16_t field_count, char *start, char *end, char *ptr, char *uncompressed, int uncomp_len, char **uncompressed_ptr)  | 1767      | uncompress        | src/dnsproxy.c |
# | MethodParameterOut | RET                                                                                                                              | 1767      | uncompress        | src/dnsproxy.c |
# | Call               | uncompress(ntohs(hdr->arcount), (char *)reply + offset, eom, ptr, uncompressed, NS_MAXDNAME, &uptr)                              | 2082      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | uptr - answers                                                                                                                   | 2097      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | uptr - answers                                                                                                                   | 2097      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | strip_domains(uncompressed, answers, uptr - answers)                                                                             | 2096      | forward_dns_reply | src/dnsproxy.c |
# | MethodParameterIn  | strip_domains(char *name, char *answers, int maxlen)                                                                             | 1896      | strip_domains     | src/dnsproxy.c |
# | Identifier         | strstr(answers, name)                                                                                                            | 1903      | strip_domains     | src/dnsproxy.c |
# | Call               | strstr(answers, name)                                                                                                            | 1903      | strip_domains     | src/dnsproxy.c |
# | Identifier         | ptr = strstr(answers, name)                                                                                                      | 1903      | strip_domains     | src/dnsproxy.c |
# | Call               | ptr + name_len                                                                                                                   | 1905      | strip_domains     | src/dnsproxy.c |
# | Identifier         | *domain = ptr + name_len                                                                                                         | 1905      | strip_domains     | src/dnsproxy.c |
# | Identifier         | strlen(domain)                                                                                                                   | 1908      | strip_domains     | src/dnsproxy.c |
# | Call               | strlen(domain)                                                                                                                   | 1908      | strip_domains     | src/dnsproxy.c |
# | Identifier         | domain_len = strlen(domain)                                                                                                      | 1908      | strip_domains     | src/dnsproxy.c |
# | Call               | domain + domain_len                                                                                                              | 1912      | strip_domains     | src/dnsproxy.c |
# | Identifier         | end - (domain + domain_len)                                                                                                      | 1912      | strip_domains     | src/dnsproxy.c |
# | Identifier         | end -= domain_len                                                                                                                | 1914      | strip_domains     | src/dnsproxy.c |
# | Identifier         | answers + data_len > end                                                                                                         | 1925      | strip_domains     | src/dnsproxy.c |
# | Identifier         | end - start                                                                                                                      | 1932      | strip_domains     | src/dnsproxy.c |
# | Call               | end - start                                                                                                                      | 1932      | strip_domains     | src/dnsproxy.c |
# | Return             | return end - start;                                                                                                              | 1932      | strip_domains     | src/dnsproxy.c |
# | MethodReturn       | RET                                                                                                                              | 1896      | strip_domains     | src/dnsproxy.c |
# | Call               | strip_domains(uncompressed, answers, uptr - answers)                                                                             | 2096      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | new_len = strip_domains(uncompressed, answers, uptr - answers)                                                                   | 2096      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | new_len < 0                                                                                                                      | 2098      | forward_dns_reply | src/dnsproxy.c |
# | Call               | header_len + new_len + fixed_len                                                                                                 | 2109      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | reply_len = header_len + new_len + fixed_len                                                                                     | 2109      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | g_try_malloc(reply_len)                                                                                                          | 2111      | forward_dns_reply | src/dnsproxy.c |
# | Call               | g_try_malloc(reply_len)                                                                                                          | 2111      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | new_reply = g_try_malloc(reply_len)                                                                                              | 2111      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | !new_reply                                                                                                                       | 2112      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | memcpy(new_reply, reply, header_len)                                                                                             | 2115      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | reply = new_reply                                                                                                                | 2119      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | reply = new_reply                                                                                                                | 2119      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | memcpy(req->resp, reply, reply_len)                                                                                              | 2131      | forward_dns_reply | src/dnsproxy.c |
# | Identifier         | cache_update(data, reply, reply_len)                                                                                             | 2134      | forward_dns_reply | src/dnsproxy.c |
# | MethodParameterIn  | cache_update(struct server_data *srv, unsigned char *msg, unsigned int msg_len)                                                  | 1383      | cache_update      | src/dnsproxy.c |
# | Call               | msg + offset                                                                                                                     | 1429      | cache_update      | src/dnsproxy.c |
# | MethodParameterIn  | parse_response(unsigned char *buf, int buflen, char *question, int qlen, uint16_t *type, uint16_t *class, int *ttl, unsigned ... | 977       | parse_response    | src/dnsproxy.c |
# | Call               | buf + sizeof(struct domain_hdr)                                                                                                  | 1004      | parse_response    | src/dnsproxy.c |
# | Identifier         | ptr = buf + sizeof(struct domain_hdr)                                                                                            | 1004      | parse_response    | src/dnsproxy.c |
# | Call               | (char *) ptr                                                                                                                     | 1006      | parse_response    | src/dnsproxy.c |
